# %% [markdown]
# # CNNs to predict optical Q
# Conduct hyperparameter search and train CNN.  Evaluate the importance of dropout for our application.

# %%
import math
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.pyplot import imread
import scipy
import pandas as pd
import tensorflow as tf
import tensorflow.keras.layers as tfl
import keras
from tensorflow.python.framework import ops
from utils import *
import json
from datetime import datetime
import os
import keras

# %%
# data_path = r"Z:\srobison\Simulation\COMSOL\DeepLearning_vNew\DataManager\testData.mat"
# data_path = r"Z:\srobison\Simulation\COMSOL\DeepLearning_vNew\DataManager\extracted_data_20241125.mat"
data_path = r"Z:\srobison\Simulation\COMSOL\DeepLearning_vNew\DataManager\extracted_data_20241201.mat"


mechFreq, optFreq, mechQ, optQ, paramsMat = load_data(data_path)

paramsShape = np.shape(paramsMat)[:-1]
num_examples = np.shape(paramsMat)[-1]
optQ_linearized = np.log10(optQ)

paramsMat_transposed = tf.transpose(paramsMat, perm = [3, 0, 1, 2])

print("shape of paramsMat_transposed: \t", np.shape(paramsMat_transposed))
print("shape of optQ: \t", np.shape(optQ))
print("number of training examples: \t", num_examples)
# Out:
# Loading data from:  Z:\srobison\Simulation\COMSOL\DeepLearning_vNew\DataManager\extracted_data_20241201.mat
#
# shape of paramsMat_transposed: 	 (1233, 11, 18, 3)
# shape of optQ: 	 (1233, 1)
# number of training examples: 	 1233

# %%
# looking at the data a bit:

x = optQ
# histogram on linear scale
plt.subplot(211)
hist, bins, _ = plt.hist(x, bins=20)
plt.yscale('log')
plt.title("11-25-24 Optical Q Distribution")

# histogram on log scale. 
# Use non-equal bin sizes, such that they look equal on log scale.
logbins = np.logspace(np.log10(bins[0]),np.log10(bins[-1]),len(bins))
plt.subplot(212)
plt.hist(x, bins=logbins)
plt.xscale('log')
plt.xlabel("optical Q")
plt.ylabel('occurences in data set')
plt.tight_layout()
plt.savefig('optical_Q_dist_2.png', dpi = 400)

# %% [markdown]
# Split the data into train and test sets using tensorflow. Because optical Q is generally sampled logrithmically, to train with a linear activation in the last layer we should take the log of the optical Q data before giving it to the model.

# %%
dataset = tf.data.Dataset.from_tensor_slices((paramsMat_transposed, optQ_linearized))

# Shuffle and split the dataset
train_size = int(0.8 * num_examples)
shuffled_data = dataset.shuffle(buffer_size=num_examples)
train_dataset = shuffled_data.take(train_size)
test_dataset = shuffled_data.skip(train_size)


## let's actually look at our data breakup
show_train_test_dist(train_dataset, test_dataset)

# let's 
batch_size = 32
train_dataset = train_dataset.batch(batch_size)
test_dataset = test_dataset.batch(batch_size)

plt.title("Target Data Distribution", fontsize= 14)
plt.xlabel("$\log (Q_{opt})$", fontsize = 14)
plt.ylabel("number", fontsize = 14)
plt.savefig('train_test_data_hist.png')
# Out:
# <>:19: SyntaxWarning: invalid escape sequence '\l'
# <>:19: SyntaxWarning: invalid escape sequence '\l'
# C:\Users\Linus\AppData\Local\Temp\ipykernel_31936\1895394255.py:19: SyntaxWarning: invalid escape sequence '\l'
#   plt.xlabel("$\log (Q_{opt})$", fontsize = 14)

# %% [markdown]
# Define the model

# %%
# define the model using the functional API structure rather than teh sequential structure in order to make it more flexible in the future.

def CNN_model(input_shape, kernel_size = [6, 2], pool_size = [8, 4], FC_nodes = [10]):
    """
    Implements the forward propagation for the model:
    CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> DENSE

    Arguments:
    input_img -- input dataset, of shape (input_shape)
    kernel_size -- list of kernel sizes for each Conv2D step
    pool_size -- list of pool sizes for each MaxPool2D step

    Returns:
    model -- TF Keras model (object containing the information for the entire training process) 
    """

    input_img = tf.keras.Input(shape=input_shape)

    Z1 = tfl.Conv2D(filters = 8, kernel_size = (kernel_size[0], kernel_size[0]), strides = 1, padding = 'same')(input_img)
    A1 = tfl.ReLU()(Z1)
    P1 = tfl.MaxPool2D(pool_size = (pool_size[0], pool_size[0]), strides = 2, padding = 'same')(A1)
    
    Z2 = tfl.Conv2D(filters = 16, kernel_size = (kernel_size[1], kernel_size[1]), strides = 1, padding = 'same')(P1)
    A2 = tfl.ReLU()(Z2)
    P2 = tfl.MaxPool2D(pool_size = (pool_size[1], pool_size[1]), strides = 1, padding = 'same')(A2)
    
    F = tfl.Flatten()(P2)

    A3 = tfl.Dense(FC_nodes[0], activation = 'relu')(F)

    output = tfl.Dense(1)(A3)
    
    model = tf.keras.Model(inputs=input_img, outputs=output)
    return model

# %%
conv_model = CNN_model(paramsShape)
optimizer = keras.optimizers.Adam(learning_rate = 0.01)
conv_model.compile(optimizer=optimizer,
                  loss='mse',
                  metrics =['mse'])

conv_model.summary()
# Out:
# Model: "functional_10"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_16 (InputLayer)          │ (None, 11, 18, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_30 (Conv2D)                   │ (None, 11, 18, 8)           │             872 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_30 (ReLU)                      │ (None, 11, 18, 8)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_30 (MaxPooling2D)      │ (None, 6, 9, 8)             │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_31 (Conv2D)                   │ (None, 6, 9, 16)            │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ re_lu_31 (ReLU)                      │ (None, 6, 9, 16)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_31 (MaxPooling2D)      │ (None, 6, 9, 16)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_15 (Flatten)                 │ (None, 864)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_23 (Dense)                     │ (None, 10)                  │           8,650 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_24 (Dense)                     │ (None, 1)                   │              11 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 10,061 (39.30 KB)
#  Trainable params: 10,061 (39.30 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = conv_model.fit(train_dataset, epochs=100, validation_data=test_dataset)
# Out:
# Epoch 1/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 27.8792 - mse: 27.8792 - val_loss: 2.1449 - val_mse: 2.1449
# Epoch 2/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7996 - mse: 1.7996 - val_loss: 1.0429 - val_mse: 1.0429
# Epoch 3/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0881 - mse: 1.0881 - val_loss: 0.9598 - val_mse: 0.9598
# Epoch 4/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1950 - mse: 1.1950 - val_loss: 1.2035 - val_mse: 1.2035
# Epoch 5/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1249 - mse: 1.1249 - val_loss: 1.0389 - val_mse: 1.0389
# Epoch 6/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1777 - mse: 1.1777 - val_loss: 1.0427 - val_mse: 1.0427
# Epoch 7/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9418 - mse: 0.9418 - val_loss: 1.1704 - val_mse: 1.1704
# Epoch 8/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9941 - mse: 0.9941 - val_loss: 0.9707 - val_mse: 0.9707
# Epoch 9/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0541 - mse: 1.0541 - val_loss: 1.1747 - val_mse: 1.1747
# Epoch 10/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0063 - mse: 1.0063 - val_loss: 1.1726 - val_mse: 1.1726
# Epoch 11/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0006 - mse: 1.0006 - val_loss: 1.0237 - val_mse: 1.0237
# Epoch 12/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0043 - mse: 1.0043 - val_loss: 0.9441 - val_mse: 0.9441
# Epoch 13/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8834 - mse: 0.8834 - val_loss: 1.0579 - val_mse: 1.0579
# Epoch 14/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0447 - mse: 1.0447 - val_loss: 1.1214 - val_mse: 1.1214
# Epoch 15/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8869 - mse: 0.8869 - val_loss: 1.0099 - val_mse: 1.0099
# Epoch 16/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1833 - mse: 1.1833 - val_loss: 1.4523 - val_mse: 1.4523
# Epoch 17/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0068 - mse: 1.0068 - val_loss: 0.9645 - val_mse: 0.9645
# Epoch 18/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1015 - mse: 1.1015 - val_loss: 0.9109 - val_mse: 0.9109
# Epoch 19/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9698 - mse: 0.9698 - val_loss: 1.2104 - val_mse: 1.2104
# Epoch 20/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0157 - mse: 1.0157 - val_loss: 1.0177 - val_mse: 1.0177
# Epoch 21/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0448 - mse: 1.0448 - val_loss: 1.0700 - val_mse: 1.0700
# Epoch 22/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8905 - mse: 0.8905 - val_loss: 0.9688 - val_mse: 0.9688
# Epoch 23/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8941 - mse: 0.8941 - val_loss: 1.2997 - val_mse: 1.2997
# Epoch 24/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9780 - mse: 0.9780 - val_loss: 1.2033 - val_mse: 1.2033
# Epoch 25/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0166 - mse: 1.0166 - val_loss: 1.1036 - val_mse: 1.1036
# Epoch 26/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.1619 - mse: 1.1619 - val_loss: 0.9622 - val_mse: 0.9622
# Epoch 27/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0163 - mse: 1.0163 - val_loss: 0.8583 - val_mse: 0.8583
# Epoch 28/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7992 - mse: 0.7992 - val_loss: 0.8542 - val_mse: 0.8542
# Epoch 29/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7985 - mse: 0.7985 - val_loss: 0.8614 - val_mse: 0.8614
# Epoch 30/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7876 - mse: 0.7876 - val_loss: 0.8950 - val_mse: 0.8950
# Epoch 31/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7284 - mse: 0.7284 - val_loss: 0.7899 - val_mse: 0.7899
# Epoch 32/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6890 - mse: 0.6890 - val_loss: 1.0051 - val_mse: 1.0051
# Epoch 33/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7477 - mse: 0.7477 - val_loss: 0.7785 - val_mse: 0.7785
# Epoch 34/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6286 - mse: 0.6286 - val_loss: 0.7875 - val_mse: 0.7875
# Epoch 35/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6115 - mse: 0.6115 - val_loss: 0.8726 - val_mse: 0.8726
# Epoch 36/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.0437 - mse: 1.0437 - val_loss: 0.8550 - val_mse: 0.8550
# Epoch 37/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8698 - mse: 0.8698 - val_loss: 0.7981 - val_mse: 0.7981
# Epoch 38/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7771 - mse: 0.7771 - val_loss: 0.9982 - val_mse: 0.9982
# Epoch 39/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.7168 - mse: 0.7168 - val_loss: 0.9571 - val_mse: 0.9571
# Epoch 40/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9006 - mse: 0.9006 - val_loss: 0.8676 - val_mse: 0.8676
# Epoch 41/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8217 - mse: 0.8217 - val_loss: 0.7493 - val_mse: 0.7493
# Epoch 42/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6784 - mse: 0.6784 - val_loss: 1.1227 - val_mse: 1.1227
# Epoch 43/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8765 - mse: 0.8765 - val_loss: 0.7689 - val_mse: 0.7689
# Epoch 44/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6121 - mse: 0.6121 - val_loss: 0.7795 - val_mse: 0.7795
# Epoch 45/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6155 - mse: 0.6155 - val_loss: 0.7362 - val_mse: 0.7362
# Epoch 46/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.
100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4535 - mse: 0.4535 - val_loss: 0.4427 - val_mse: 0.4427
# Epoch 80/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3847 - mse: 0.3847 - val_loss: 1.0533 - val_mse: 1.0533
# Epoch 81/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.5311 - mse: 0.5311 - val_loss: 0.7604 - val_mse: 0.7604
# Epoch 82/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4352 - mse: 0.4352 - val_loss: 0.4865 - val_mse: 0.4865
# Epoch 83/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3112 - mse: 0.3112 - val_loss: 0.5836 - val_mse: 0.5836
# Epoch 84/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3630 - mse: 0.3630 - val_loss: 0.4224 - val_mse: 0.4224
# Epoch 85/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2900 - mse: 0.2900 - val_loss: 0.4733 - val_mse: 0.4733
# Epoch 86/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3274 - mse: 0.3274 - val_loss: 0.3873 - val_mse: 0.3873
# Epoch 87/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3142 - mse: 0.3142 - val_loss: 0.7374 - val_mse: 0.7374
# Epoch 88/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4662 - mse: 0.4662 - val_loss: 0.5341 - val_mse: 0.5341
# Epoch 89/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3493 - mse: 0.3493 - val_loss: 0.3720 - val_mse: 0.3720
# Epoch 90/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2888 - mse: 0.2888 - val_loss: 0.3566 - val_mse: 0.3566
# Epoch 91/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2949 - mse: 0.2949 - val_loss: 0.3626 - val_mse: 0.3626
# Epoch 92/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2779 - mse: 0.2779 - val_loss: 0.5522 - val_mse: 0.5522
# Epoch 93/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3433 - mse: 0.3433 - val_loss: 0.4134 - val_mse: 0.4134
# Epoch 94/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3401 - mse: 0.3401 - val_loss: 0.3557 - val_mse: 0.3557
# Epoch 95/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2762 - mse: 0.2762 - val_loss: 0.4742 - val_mse: 0.4742
# Epoch 96/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.3290 - mse: 0.3290 - val_loss: 0.3653 - val_mse: 0.3653
# Epoch 97/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2524 - mse: 0.2524 - val_loss: 0.3799 - val_mse: 0.3799
# Epoch 98/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2949 - mse: 0.2949 - val_loss: 0.3409 - val_mse: 0.3409
# Epoch 99/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2435 - mse: 0.2435 - val_loss: 0.3597 - val_mse: 0.3597
# Epoch 100/100
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2844 - mse: 0.2844 - val_loss: 0.4094 - val_mse: 0.4094

# %%
conv_model.evaluate(test_dataset)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4368 - mse: 0.4368
# [0.40938955545425415, 0.40938955545425415]

# %%
df_loss_acc = pd.DataFrame(history.history)
print(df_loss_acc.columns)
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
df_mse= df_loss_acc[['mse','val_mse']]
df_mse.rename(columns={'mse':'train','val_mse':'validation'},inplace=True)

df_loss.plot(title='Model loss',figsize=(12,8)).set(xlabel='Epoch',ylabel='Loss')
# df_mse.plot(title='Model Accuracy',figsize=(12,8)).set(xlabel='Epoch',ylabel='MSE')
# Out:
# Index(['loss', 'mse', 'val_loss', 'val_mse'], dtype='object')
# C:\Users\Linus\AppData\Local\Temp\ipykernel_33724\747123822.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
# C:\Users\Linus\AppData\Local\Temp\ipykernel_33724\747123822.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mse.rename(columns={'mse':'train','val_mse':'validation'},inplace=True)
# [Text(0.5, 0, 'Epoch'), Text(0, 0.5, 'Loss')]

# %% [markdown]
# With a trained model in hand it might be nice to see individual examples of how good it is at predicting...

# %%
train_numbers = np.arange(10)
for train_number in train_numbers:
    test_iterator = iter(test_dataset)
    
    # Get a single batch (you can also use next(test_iterator) for just one item in the batch)
    batch_X, batch_Y = next(test_iterator)
    
    # Extract a single input and label pair from the batch
    # For example, take the first item from the batch
    single_input = batch_X[train_number].numpy()  # Convert to NumPy array
    single_label = batch_Y[train_number].numpy()  # Convert to NumPy array
    
    single_input =  np.expand_dims(single_input, axis=0) 
    
    prediction = conv_model.predict(single_input)
    
    print("predicted Q = {}".format(np.exp(prediction)))
    print("true Q = {}".format(np.exp(single_label)))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# predicted Q = [[2113.62]]
# true Q = [1764.473252]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# predicted Q = [[6315.2036]]
# true Q = [10275.52294081]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# predicted Q = [[1875.7639]]
# true Q = [3040.12035094]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# predicted Q = [[4212.159]]
# true Q = [12165.39992799]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step
# predicted Q = [[520.87714]]
# true Q = [900.82855068]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# predicted Q = [[8942.716]]
# true Q = [8187.85774313]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# predicted Q = [[12601.296]]
# true Q = [24255.90580533]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# predicted Q = [[26304.266]]
# true Q = [10110.06770586]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# predicted Q = [[12526.242]]
# true Q = [17853.10393943]
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step
# predicted Q = [[4684.145]]
# true Q = [5647.03080601]

# %% [markdown]
# Seems like the model is having a hard time with large Q modes and low Q modes.  Need to think about good ways to give these outliers appropriate weight. ie. model is high bias currently.  however, gets the MSE down below 1 so we are consistently within an order of magnitude ~ this is sort of good.

# %% [markdown]
# ## parametrizing the model for a random hyperparam search

# %%
def hyper_param_search(kernel_sizes, filters, pool_sizes, FC_nodes, lr, verbose = 2):
    """
    takes hyperparameters as input, then initializes and trains a model.
    _____________________________________________________________________
    Inputs:
        kernel_sizes - the kernel sizes for each convolutional layer
        filters - the number of filters used for each convolutional layer
        pool_size - the pool size for max pool operations between convolutions
        FC_node - the number of nodes in each dense layer of the model
        lr - the learning rate for the adam optimizer
    Outputs:
        performance - the performance of the trained model on the dev dataset
    """

    def CNN_model(input_shape, kernel_sizes = [6, 2], filters = [8, 16], pool_sizes = [8, 4], FC_nodes = [10]):
        """
        Implements the forward propagation for the model:
        CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> DENSE
    
        Arguments:
        input_img -- input dataset, of shape (input_shape)
        kernel_size -- list of kernel sizes for each Conv2D step
        pool_size -- list of pool sizes for each MaxPool2D step
    
        Returns:
        model -- TF Keras model (object containing the information for the entire training process) 
        """
    
        input_img = tf.keras.Input(shape=input_shape)
    
        P = input_img
        
        for kernel_size, num_filters, pool_size in zip(kernel_sizes, filters, pool_sizes):
            Z = tfl.Conv2D(filters = num_filters, kernel_size = (kernel_size, kernel_size), strides = 1, padding = 'same')(P)
            A = tfl.ReLU()(Z)
            P = tfl.MaxPool2D(pool_size = (pool_size, pool_size), strides = 2, padding = 'same')(A)
        
        F = tfl.Flatten()(P)
        A = F

        for node in FC_nodes:
            A = tfl.Dense(node, activation = 'relu')(A)
    
        output = tfl.Dense(1)(A)
        
        model = tf.keras.Model(inputs=input_img, outputs=output)
        return model
    
    conv_model = CNN_model(paramsShape, kernel_sizes, filters, pool_sizes, FC_nodes)
    optimizer = keras.optimizers.Adam(learning_rate = lr)
    conv_model.compile(optimizer=optimizer,
                      loss='mse',
                      metrics =['mse'])

    history = conv_model.fit(train_dataset, epochs=100, validation_data=test_dataset, verbose = verbose)
    performance = conv_model.evaluate(test_dataset)
    return performance

# %%
def gen_random_hyperparams():
    '''
    generates hyperparameters to feed to the parameterized CNN model
        randomly chooses a number of convolutional + maxpool blocks between 1 and 6
        randomly selects set of conv kernel sizes, max pool sizes, and conv filter numbers
        randomly chooses number of dense layers between 1 and 4
        randomly chooses number of nodes in each dense layer
        randomly selects a learning rate on a log scale in the range 1e-1 to 1e-5

    The parameters are sorted such that the model gets increasingly more channels, the mask for conv and maxpool shrinks
    and the fully connected layers go to fewer and fewer nodes moving from input to output of the model.
    '''
    # number of conv + pool layers there will be, between 1 and 6
    num_conv_itters = np.random.randint(1, 6)

    # create list of random integers for the kernel sizes, pool sizes, and num_filers.  The filter numbers should increase
    # while the kernel sizes and pool sizes should decrease.
    kernel_sizes = [np.random.randint(1, 11) for _ in range(num_conv_itters)] # 11 is natural upper bound as this is the dimension of the input on one axis
    kernel_sizes = sorted(kernel_sizes, reverse=True)

    pool_sizes = [np.random.randint(1, 11) for _ in range(num_conv_itters)] # 11 is natural upper bound as this is the dimension of the input on one axis
    pool_sizes = sorted(pool_sizes, reverse=True)

    filters = [np.random.randint(1, 25) for _ in range(num_conv_itters)] # the filters should be sorted starting with fewer filters and going to more
    filters = sorted(filters, reverse=False)

    num_dense_itters = np.random.randint(1, 4)
    FC_nodes = [2**np.random.randint(1, 8) for _ in range(num_dense_itters)] # 11 is natural upper bound as this is the dimension of the input on one axis
    FC_nodes = sorted(FC_nodes, reverse=True)

    # randomly generate the learning rate on a log scale
    rng = 4 # range of exponents
    center = 3 # center of distribution
    lr = 10**-(np.random.rand()*rng + (center-rng/2))

    return kernel_sizes, filters, pool_sizes, FC_nodes, lr



# check that this works once.
performance = hyper_param_search(*gen_random_hyperparams())
print(performance)
# Out:
# Epoch 1/100
# 31/31 - 1s - 31ms/step - loss: 12.1238 - mse: 12.1238 - val_loss: 1.5907 - val_mse: 1.5907
# Epoch 2/100
# 31/31 - 0s - 4ms/step - loss: 1.1039 - mse: 1.1039 - val_loss: 0.9346 - val_mse: 0.9346
# Epoch 3/100
# 31/31 - 0s - 3ms/step - loss: 0.8925 - mse: 0.8925 - val_loss: 0.8788 - val_mse: 0.8788
# Epoch 4/100
# 31/31 - 0s - 3ms/step - loss: 0.8364 - mse: 0.8364 - val_loss: 0.8620 - val_mse: 0.8620
# Epoch 5/100
# 31/31 - 0s - 3ms/step - loss: 0.8470 - mse: 0.8470 - val_loss: 0.8552 - val_mse: 0.8552
# Epoch 6/100
# 31/31 - 0s - 3ms/step - loss: 0.8407 - mse: 0.8407 - val_loss: 0.8671 - val_mse: 0.8671
# Epoch 7/100
# 31/31 - 0s - 3ms/step - loss: 0.8456 - mse: 0.8456 - val_loss: 0.8988 - val_mse: 0.8988
# Epoch 8/100
# 31/31 - 0s - 3ms/step - loss: 0.8299 - mse: 0.8299 - val_loss: 0.7749 - val_mse: 0.7749
# Epoch 9/100
# 31/31 - 0s - 3ms/step - loss: 0.8339 - mse: 0.8339 - val_loss: 0.9263 - val_mse: 0.9263
# Epoch 10/100
# 31/31 - 0s - 3ms/step - loss: 0.8384 - mse: 0.8384 - val_loss: 0.8556 - val_mse: 0.8556
# Epoch 11/100
# 31/31 - 0s - 3ms/step - loss: 0.8740 - mse: 0.8740 - val_loss: 0.8203 - val_mse: 0.8203
# Epoch 12/100
# 31/31 - 0s - 3ms/step - loss: 0.8362 - mse: 0.8362 - val_loss: 0.8413 - val_mse: 0.8413
# Epoch 13/100
# 31/31 - 0s - 3ms/step - loss: 0.8508 - mse: 0.8508 - val_loss: 0.8665 - val_mse: 0.8665
# Epoch 14/100
# 31/31 - 0s - 3ms/step - loss: 0.8428 - mse: 0.8428 - val_loss: 0.8481 - val_mse: 0.8481
# Epoch 15/100
# 31/31 - 0s - 3ms/step - loss: 0.8290 - mse: 0.8290 - val_loss: 0.7782 - val_mse: 0.7782
# Epoch 16/100
# 31/31 - 0s - 3ms/step - loss: 0.8749 - mse: 0.8749 - val_loss: 0.9229 - val_mse: 0.9229
# Epoch 17/100
# 31/31 - 0s - 3ms/step - loss: 0.8490 - mse: 0.8490 - val_loss: 0.8638 - val_mse: 0.8638
# Epoch 18/100
# 31/31 - 0s - 3ms/step - loss: 0.8497 - mse: 0.8497 - val_loss: 0.7976 - val_mse: 0.7976
# Epoch 19/100
# 31/31 - 0s - 3ms/step - loss: 0.8436 - mse: 0.8436 - val_loss: 0.7021 - val_mse: 0.7021
# Epoch 20/100
# 31/31 - 0s - 3ms/step - loss: 0.8196 - mse: 0.8196 - val_loss: 0.7884 - val_mse: 0.7884
# Epoch 21/100
# 31/31 - 0s - 3ms/step - loss: 0.8547 - mse: 0.8547 - val_loss: 0.7900 - val_mse: 0.7900
# Epoch 22/100
# 31/31 - 0s - 3ms/step - loss: 0.8228 - mse: 0.8228 - val_loss: 0.8760 - val_mse: 0.8760
# Epoch 23/100
# 31/31 - 0s - 3ms/step - loss: 0.8484 - mse: 0.8484 - val_loss: 0.8501 - val_mse: 0.8501
# Epoch 24/100
# 31/31 - 0s - 3ms/step - loss: 0.8684 - mse: 0.8684 - val_loss: 0.7623 - val_mse: 0.7623
# Epoch 25/100
# 31/31 - 0s - 3ms/step - loss: 0.8383 - mse: 0.8383 - val_loss: 0.9015 - val_mse: 0.9015
# Epoch 26/100
# 31/31 - 0s - 3ms/step - loss: 0.8982 - mse: 0.8982 - val_loss: 1.0069 - val_mse: 1.0069
# Epoch 27/100
# 31/31 - 0s - 3ms/step - loss: 0.8476 - mse: 0.8476 - val_loss: 0.8399 - val_mse: 0.8399
# Epoch 28/100
# 31/31 - 0s - 3ms/step - loss: 0.8560 - mse: 0.8560 - val_loss: 0.7179 - val_mse: 0.7179
# Epoch 29/100
# 31/31 - 0s - 3ms/step - loss: 0.7811 - mse: 0.7811 - val_loss: 0.7999 - val_mse: 0.7999
# Epoch 30/100
# 31/31 - 0s - 3ms/step - loss: 0.8233 - mse: 0.8233 - val_loss: 0.8565 - val_mse: 0.8565
# Epoch 31/100
# 31/31 - 0s - 3ms/step - loss: 0.8121 - mse: 0.8121 - val_loss: 0.7528 - val_mse: 0.7528
# Epoch 32/100
# 31/31 - 0s - 3ms/step - loss: 0.7940 - mse: 0.7940 - val_loss: 0.8070 - val_mse: 0.8070
# Epoch 33/100
# 31/31 - 0s - 3ms/step - loss: 0.1032 - mse: 0.1032 - val_loss: 0.1162 - val_mse: 0.1162
# Epoch 99/100
# 31/31 - 0s - 3ms/step - loss: 0.1035 - mse: 0.1035 - val_loss: 0.1204 - val_mse: 0.1204
# Epoch 100/100
# 31/31 - 0s - 3ms/step - loss: 0.1447 - mse: 0.1447 - val_loss: 0.1473 - val_mse: 0.1473
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1357 - mse: 0.1357
# [0.13883985579013824, 0.13883985579013824]

# %% [markdown]
# The below cell crashed the window because my computer ran out of memory.  There must be a way to close the model after running it so that it doesn't continue to eat memory.  The dictionary could also have gotten too big, but this seems highly improbable given python's ability to store large datasets.

# %%
def update_hyperparams(hyperparams, params):
    '''
    adds row containing 'params' to the hyperparams dictionary

    params - tuple of form (kernel_sizes, filters, pool_sizes, FC_nodes, lr)
    '''
    for val, key in zip(params, hyperparams.keys()):
        hyperparams[key].append(val)

savepath = 'CNN_Optical_Q_hyperparams_{}.json'.format(datetime.now().strftime("%Y%m%d-%H%M%S"))


hyperparams = {"kernel_sizes":[], "filters":[], "pool_sizes":[], "FC_nodes":[], "lr":[], "performance":[]}
for i in range(20):
    print(f'starting parameter combination {i}')
    params = gen_random_hyperparams()
    performance = hyper_param_search(*params, verbose = 0)
    params = list(params)
    params.append(performance)
    print("params: ", params, "\n")
    update_hyperparams(hyperparams, params)
    write_json(hyperparams, savepath)
# Out:
# starting parameter combination 0
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 14.6644 - mse: 14.6644
# params:  [[9, 7, 6, 1], [4, 10, 16, 22], [9, 4, 2, 2], [4, 2], 0.0002579476269334547, [14.403124809265137, 14.403124809265137]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_20241201-210005.json
# starting parameter combination 1
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9701 - mse: 0.9701
# params:  [[9, 7, 4, 1], [5, 5, 7, 24], [10, 7, 6, 2], [32, 16], 0.07695672491126856, [0.9765076637268066, 0.9765076637268066]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_20241201-210005.json
# starting parameter combination 2
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8675 - mse: 0.8675
# params:  [[10, 6, 1], [1, 4, 20], [10, 9, 6], [32, 8], 4.8898738121608965e-05, [0.8854547739028931, 0.8854547739028931]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_20241201-210005.json
# starting parameter combination 3
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 12.8160 - mse: 12.8160
# params:  [[5, 5, 2, 1], [3, 16, 21, 21], [8, 8, 6, 4], [128, 2], 0.0003229714256820455, [13.308955192565918, 13.308955192565918]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_20241201-210005.json
# starting parameter combination 4
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1526 - mse: 0.1526
# params:  [[10, 6, 6, 3, 2], [6, 9, 14, 23, 23], [8, 7, 3, 2, 1], [16], 0.002226159304945563, [0.1604432314634323, 0.1604432314634323]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_20241201-210005.json
# starting parameter combination 5
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0689 - mse: 0.0689
# params:  [[8, 7, 4, 3], [7, 14, 16, 20], [9, 9, 8, 5], [32, 8], 0.003934897318396649, [0.06947333365678787, 0.06947333365678787]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_20241201-210005.json
# starting parameter combination 6
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1827 - mse: 0.1827
# params:  [[1], [22], [4], [128, 16], 0.003605718691927074, [0.1873130202293396, 0.1873130202293396]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_20241201-210005.json
# starting parameter combination 7
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.8341 - mse: 0.8341
# params:  [[10, 3, 3, 2, 1], [8, 9, 13, 14, 19], [10, 10, 7, 5, 4], [4], 4.7172211188231055e-05, [0.7992081046104431, 0.7992081046104431]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_20241201-210005.json
# starting parameter combination 8
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21.8422 - mse: 21.8422
# params:  [[7, 3], [14, 21], [2, 1], [16, 4], 1.586528911667573e-05, [21.64344024658203, 21.64344024658203]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_20241201-210005.json
# starting parameter combination 9
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.2295 - mse: 0.2295
# params:  [[10, 9, 9], [4, 19, 21], [10, 5, 2], [128, 8, 8], 0.00021902112342682143, [0.2361476868391037, 0.2361476868391037]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_20241201-210005.json
# starting parameter combination 10
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8854 - mse: 0.8854
# params:  [[9, 8, 7, 5, 4], [4, 4, 11, 19, 19], [9, 8, 5, 2, 2], [8], 0.029737653407131807, [0.8340034484863281, 0.8340034484863281]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_20241201-210005.json
# starting parameter combination 11
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1896 - mse: 0.1896
# params:  [[9, 9, 7, 3], [6, 9, 16, 20], [8, 6, 4, 3], [8], 0.00017164207788653582, [0.1957298368215561, 0.1957298368215561]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_20241201-210005.json
# starting parameter combination 12
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.2319 - mse: 0.2319
# params:  [[9, 1], [5, 17], [8, 5], [16], 0.025823708047237565, [0.21241812407970428, 0.21241812407970428]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_20241201-210005.json
# starting parameter combination 13
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1680 - mse: 0.1680
# params:  [[9, 7, 7, 3, 1], [5, 6, 8, 19, 20], [10, 8, 7, 5, 3], [64, 32, 4], 0.0010430158461628015, [0.16969870030879974, 0.16969870030879974]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_20241201-210005.json
# starting parameter combination 14
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.7154 - mse: 0.7154
# params:  [[7], [2], [1], [4], 0.00019513328368609645, [0.7606805562973022, 0.7606805562973022]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_20241201-210005.json
# starting parameter combination 15
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8783 - mse: 0.8783
# params:  [[8, 7, 6, 6, 3], [1, 4, 15, 22, 23], [4, 2, 1, 1, 1], [128, 4], 0.0008457455297696737, [1.0372817516326904, 1.0372817516326904]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_20241201-210005.json
# starting parameter combination 16
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.9079 - mse: 0.9079
# params:  [[3], [17], [3], [16], 1.0869531969844947e-05, [1.004335641860962, 1.004335641860962]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_20241201-210005.json
# starting parameter combination 17
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.8845 - mse: 0.8845
# params:  [[8], [8], [8], [128, 64, 32], 0.01806422601194744, [0.8552143573760986, 0.8552143573760986]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_20241201-210005.json
# starting parameter combination 18
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1692 - mse: 0.1692
# params:  [[5, 3], [16, 17], [4, 1], [64, 32, 4], 0.00015790586996277393, [0.1725665032863617, 0.1725665032863617]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_20241201-210005.json
# starting parameter combination 19
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 19.8972 - mse: 19.8972
# params:  [[8], [4], [9], [32, 4], 4.95822615389214e-05, [20.3636531829834, 20.3636531829834]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_20241201-210005.json

# %%
path = "CNN_Optical_Q_hyperparams_20241125-234124.json"

loaded_data = read_json(path)

print("Loaded data:", pd.DataFrame(loaded_data))
df = pd.DataFrame(loaded_data)
df.to_csv(path.split()[0] + '.csv')
# Out:
# Loaded data:          kernel_sizes              filters        pool_sizes      FC_nodes  \
# 0    [10, 8, 4, 1, 1]   [7, 7, 18, 19, 21]  [10, 8, 4, 3, 1]       [64, 2]
# 1        [7, 6, 5, 1]      [8, 19, 19, 21]     [10, 8, 6, 2]     [2, 2, 2]
# 2          [10, 5, 2]         [14, 19, 23]         [9, 8, 4]         [128]
# 3     [8, 8, 7, 4, 2]  [4, 15, 17, 19, 20]   [9, 9, 8, 4, 1]    [16, 8, 4]
# 4          [10, 3, 3]          [6, 15, 24]         [7, 7, 6]    [64, 8, 4]
# ..                ...                  ...               ...           ...
# 195               [5]                  [6]               [2]  [128, 16, 4]
# 196        [10, 2, 1]         [12, 21, 23]        [10, 4, 1]     [8, 2, 2]
# 197         [8, 6, 6]         [20, 22, 23]         [6, 6, 2]          [64]
# 198      [9, 2, 2, 1]     [16, 16, 20, 23]      [8, 7, 4, 1]          [16]
# 199     [10, 9, 7, 4]       [1, 8, 13, 21]      [8, 7, 7, 5]           [8]
#
#            lr                                 performance
# 0    0.003352  [0.19681121408939362, 0.19681121408939362]
# 1    0.078205        [1.98764967918396, 1.98764967918396]
# 2    0.000608    [0.1736876368522644, 0.1736876368522644]
# 3    0.000062    [1.8851404190063477, 1.8851404190063477]
# 4    0.024571      [1.861795425415039, 1.861795425415039]
# ..        ...                                         ...
# 195  0.008790  [0.19927099347114563, 0.19927099347114563]
# 196  0.000011    [29.131322860717773, 29.131322860717773]
# 197  0.013127      [2.010328531265259, 2.010328531265259]
# 198  0.000968  [0.18302057683467865, 0.18302057683467865]
# 199  0.001247  [0.21407581865787506, 0.21407581865787506]
#
# [200 rows x 6 columns]

# %% [markdown]
# # Hyperparmeter search with dropout

# %%
def hyper_param_search_dropout(kernel_sizes, filters, pool_sizes, FC_nodes, dropouts, lr, verbose = 2):
    """
    takes hyperparameters as input, then initializes and trains a model.
    _____________________________________________________________________
    Inputs:
        kernel_sizes - the kernel sizes for each convolutional layer
        filters - the number of filters used for each convolutional layer
        pool_size - the pool size for max pool operations between convolutions
        FC_node - the number of nodes in each dense layer of the model
        lr - the learning rate for the adam optimizer
    Outputs:
        performance - the performance of the trained model on the dev dataset
    """

    def CNN_model(input_shape, kernel_sizes = [6, 2], filters = [8, 16], pool_sizes = [8, 4], FC_nodes = [10]):
        """
        Implements the forward propagation for the model:
        CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> DENSE
    
        Arguments:
        input_img -- input dataset, of shape (input_shape)
        kernel_size -- list of kernel sizes for each Conv2D step
        pool_size -- list of pool sizes for each MaxPool2D step
    
        Returns:
        model -- TF Keras model (object containing the information for the entire training process) 
        """
    
        input_img = tf.keras.Input(shape=input_shape)
    
        P = input_img
        
        for kernel_size, num_filters, pool_size in zip(kernel_sizes, filters, pool_sizes):
            Z = tfl.Conv2D(filters = num_filters, kernel_size = (kernel_size, kernel_size), strides = 1, padding = 'same')(P)
            A = tfl.ReLU()(Z)
            P = tfl.MaxPool2D(pool_size = (pool_size, pool_size), strides = 2, padding = 'same')(A)
        
        F = tfl.Flatten()(P)
        A = F

        for node, dropout in zip(FC_nodes, dropouts):
            A = tfl.Dense(node, activation = 'relu')(A)
            A = tfl.Dropout(rate = dropout)(A)
            
            
        output = tfl.Dense(1)(A)
        
        model = tf.keras.Model(inputs=input_img, outputs=output)
        return model
    
    conv_model = CNN_model(paramsShape, kernel_sizes, filters, pool_sizes, FC_nodes)
    optimizer = keras.optimizers.Adam(learning_rate = lr)
    conv_model.compile(optimizer=optimizer,
                      loss='mse',
                      metrics =['mse'])

    history = conv_model.fit(train_dataset, epochs=100, validation_data=test_dataset, verbose = verbose)
    performance = conv_model.evaluate(test_dataset)
    return performance

# %%
def gen_random_hyperparams_dropout():
    '''
    generates hyperparameters to feed to the parameterized CNN model
        randomly chooses a number of convolutional + maxpool blocks between 1 and 6
        randomly selects set of conv kernel sizes, max pool sizes, and conv filter numbers
        randomly chooses number of dense layers between 1 and 4
        randomly chooses number of nodes in each dense layer
        randomly selects a learning rate on a log scale in the range 1e-1 to 1e-5

    The parameters are sorted such that the model gets increasingly more channels, the mask for conv and maxpool shrinks
    and the fully connected layers go to fewer and fewer nodes moving from input to output of the model.
    '''
    # number of conv + pool layers there will be, between 1 and 6
    num_conv_itters = np.random.randint(1, 6)

    # create list of random integers for the kernel sizes, pool sizes, and num_filers.  The filter numbers should increase
    # while the kernel sizes and pool sizes should decrease.
    kernel_sizes = [np.random.randint(1, 11) for _ in range(num_conv_itters)] # 11 is natural upper bound as this is the dimension of the input on one axis
    kernel_sizes = sorted(kernel_sizes, reverse=True)

    pool_sizes = [np.random.randint(1, 11) for _ in range(num_conv_itters)] # 11 is natural upper bound as this is the dimension of the input on one axis
    pool_sizes = sorted(pool_sizes, reverse=True)

    filters = [np.random.randint(1, 25) for _ in range(num_conv_itters)] # the filters should be sorted starting with fewer filters and going to more
    filters = sorted(filters, reverse=False)

    num_dense_itters = np.random.randint(1, 4)
    FC_nodes = [2**np.random.randint(1, 8) for _ in range(num_dense_itters)] # 11 is natural upper bound as this is the dimension of the input on one axis
    FC_nodes = sorted(FC_nodes, reverse=True)
    
    dropouts = list(10**(np.random.uniform(-4, -0.5, size = num_dense_itters)))

    # randomly generate the learning rate on a log scale
    rng = 4 # range of exponents
    center = 3 # center of distribution
    lr = 10**-(np.random.rand()*rng + (center-rng/2))

    return kernel_sizes, filters, pool_sizes, FC_nodes, dropouts, lr


# check that this works once.
params = gen_random_hyperparams_dropout()
print(params)
performance = hyper_param_search_dropout(*params, verbose = 0)
print(performance)
# Out:
# ([6, 1], [11, 20], [9, 1], [32, 8], [0.001154702576481922, 0.04330288366189738], 2.5965535204790357e-05)
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.9028 - mse: 1.9028
# [2.2659685611724854, 2.2659685611724854]

# %%
def update_hyperparams_dropout(hyperparams_dropout, params):
    '''
    adds row containing 'params' to the hyperparams_dropout dictionary

    params - tuple of form (kernel_sizes, filters, pool_sizes, FC_nodes, lr)
    '''
    for val, key in zip(params, hyperparams_dropout.keys()):
        hyperparams_dropout[key].append(val)

savepath = 'CNN_Optical_Q_hyperparams_dropout_{}.json'.format(datetime.now().strftime("%Y%m%d-%H%M%S"))


hyperparams_dropout = {"kernel_sizes":[], "filters":[], "pool_sizes":[], "FC_nodes":[], "dropouts": [], "lr":[], "performance":[]}
for i in range(200):
    print(f'starting parameter combination {i}')
    params = gen_random_hyperparams_dropout()
    performance = hyper_param_search_dropout(*params, verbose = 0)
    params = list(params)
    params.append(performance)
    print("params: ", params, "\n")
    update_hyperparams_dropout(hyperparams_dropout, params)
    write_json(hyperparams_dropout, savepath)
# Out:
# starting parameter combination 0
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.4923 - mse: 1.4923
# params:  [[9, 1], [2, 22], [9, 8], [8], [0.0005645075954411018], 0.0025062714229451264, [1.7337000370025635, 1.7337000370025635]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_dropout_20241126-092131.json
# starting parameter combination 1
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2363 - mse: 0.2363
# params:  [[10, 9, 9, 8, 4], [5, 13, 18, 19, 19], [10, 8, 7, 5, 2], [8, 2], [0.0031308458554176453, 0.00022984982726502942], 0.004838658726124077, [0.27787426114082336, 0.27787426114082336]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_dropout_20241126-092131.json
# starting parameter combination 2
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 2
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.4412 - mse: 3.4412
# params:  [[10, 6, 5, 3, 2], [1, 8, 9, 14, 19], [10, 7, 7, 6, 5], [16, 4, 2], [0.0007785653279411362, 0.24339359446205003, 0.08743388159463603], 0.00029756820230828564, [4.116234302520752, 4.116234302520752]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_dropout_20241126-092131.json
# starting parameter combination 190
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6608 - mse: 1.6608
# params:  [[7, 5, 3, 3, 1], [4, 10, 15, 18, 22], [10, 9, 8, 5, 4], [16, 8], [0.22670599554113333, 0.1976682684086239], 0.008110865824896155, [1.9589570760726929, 1.9589570760726929]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_dropout_20241126-092131.json
# starting parameter combination 191
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6204 - mse: 1.6204
# params:  [[9, 9, 7, 4], [3, 4, 10, 15], [8, 7, 7, 4], [128, 128, 64], [0.0003288582451937517, 0.0005307147171223746, 0.05425185117304204], 8.416404999979103e-05, [1.9043978452682495, 1.9043978452682495]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_dropout_20241126-092131.json
# starting parameter combination 192
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.7490 - mse: 1.7490
# params:  [[3, 2, 1], [9, 19, 20], [4, 3, 2], [128], [0.0005744041362017246], 8.199985794953611e-05, [2.0725975036621094, 2.0725975036621094]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_dropout_20241126-092131.json
# starting parameter combination 193
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 1.7851 - mse: 1.7851
# params:  [[6, 4], [14, 22], [8, 2], [64], [0.16314141087434908], 2.6947186545335306e-05, [2.116779088973999, 2.116779088973999]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_dropout_20241126-092131.json
# starting parameter combination 194
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6727 - mse: 1.6727
# params:  [[10, 5, 4, 4, 3], [4, 5, 7, 18, 22], [9, 9, 6, 5, 4], [8, 4, 2], [0.0009601265896524261, 0.00023077468314758792, 0.012524618410595028], 0.005006835793837089, [1.9743999242782593, 1.9743999242782593]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_dropout_20241126-092131.json
# starting parameter combination 195
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 2.2795 - mse: 2.2795
# params:  [[8], [23], [9], [64, 4], [0.0028476422572366513, 0.17999547843890396], 0.0002410889901212988, [2.716749668121338, 2.716749668121338]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_dropout_20241126-092131.json
# starting parameter combination 196
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.2190 - mse: 0.2190
# params:  [[5, 4, 3, 1, 1], [3, 5, 11, 12, 24], [10, 7, 6, 4, 2], [128, 32, 2], [0.00010691607460934781, 0.16669869794841555, 0.00017303918859131294], 0.008426019379677383, [0.228141650557518, 0.228141650557518]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_dropout_20241126-092131.json
# starting parameter combination 197
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.6509 - mse: 1.6509
# params:  [[10, 8, 5, 4, 4], [1, 5, 9, 17, 23], [8, 5, 4, 4, 3], [128, 8], [0.0008376668968616526, 0.26507393571461974], 0.041816761109866735, [1.9460219144821167, 1.9460219144821167]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_dropout_20241126-092131.json
# starting parameter combination 198
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1829 - mse: 0.1829
# params:  [[8, 5], [1, 18], [7, 6], [8], [0.0021049201124960166], 0.009322147396936098, [0.20173034071922302, 0.20173034071922302]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_dropout_20241126-092131.json
# starting parameter combination 199
# 7/7 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 26.5893 - mse: 26.5893
# params:  [[7, 2], [15, 24], [3, 3], [2], [0.035675995849600364], 1.4662686523549357e-05, [29.03666114807129, 29.03666114807129]]
#
# Writing data to:  CNN_Optical_Q_hyperparams_dropout_20241126-092131.json

# %%
path = "CNN_Optical_Q_hyperparams_20241201-210005.json"

loaded_data = read_json(path)

df = pd.DataFrame(loaded_data)
df.to_csv(path.split(".")[0] + '.csv')

# %% [markdown]
# ## Define More Parametrized CNN
# Used for manual tinkering with model parameters and later used for transfer learning.

# %%
def CNN_model(input_shape, kernel_sizes = [6, 2], filters = [8, 16], pool_sizes = [8, 4], FC_nodes = [10], lr = 0.01):
        """
        Implements the forward propagation for the model:
        CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> DENSE
    
        Arguments:
        input_img -- input dataset, of shape (input_shape)
        kernel_size -- list of kernel sizes for each Conv2D step
        pool_size -- list of pool sizes for each MaxPool2D step
    
        Returns:
        model -- TF Keras model (object containing the information for the entire training process) 
        """
    
        input_img = tf.keras.Input(shape=input_shape)
    
        P = input_img
        
        for kernel_size, num_filters, pool_size in zip(kernel_sizes, filters, pool_sizes):
            Z = tfl.Conv2D(filters = num_filters, kernel_size = (kernel_size, kernel_size), strides = 1, padding = 'same')(P)
            A = tfl.ReLU()(Z)
            P = tfl.MaxPool2D(pool_size = (pool_size, pool_size), strides = 2, padding = 'same')(A)
        
        F = tfl.Flatten()(P)
        A = F

        for node in FC_nodes:
            A = tfl.Dense(node, activation = 'relu')(F)
    
        output = tfl.Dense(1)(A)
        
        model = tf.keras.Model(inputs=input_img, outputs=output)
        optimizer = keras.optimizers.Adam(learning_rate = lr)
        model.compile(optimizer=optimizer,
                          loss='mse',
                          metrics =['mse'])
        return model

# %%
## train model with best performing parameters from the random search
## best performer from CNN_Optical_Q_hyperparams_20241112-212236.json
# kernel_sizes, filters, pool_sizes, FC_nodes, lr = [10, 10], [23, 24], [10, 2], [64], 0.0019715835257217303
# kernel_sizes, filters, pool_sizes, FC_nodes, lr = [9, 4, 4, 2],	[15, 22, 23, 23], [10, 6, 1, 1], [128, 128, 16], 0.0024823465484887066
# kernel_sizes, filters, pool_sizes, FC_nodes, lr = [10, 5], [16, 24], [10, 1], [128, 64, 16], 0.0010438169495987548
kernel_sizes, filters, pool_sizes, FC_nodes, lr = [3, 2], [16, 24], [1], [64], 0.0010438169495987548



conv_model = CNN_model(paramsShape, kernel_sizes, filters, pool_sizes, FC_nodes, lr)

history = conv_model.fit(train_dataset, epochs=200, validation_data=test_dataset)
performance = conv_model.evaluate(test_dataset)

# save the model weights for transfer learning or just bringing the model back to life later
model_name = "conv_model_{}".format(datetime.now().strftime("%Y%m%d-%H%M%S"))

weights_path = model_name + ".weights.h5"
conv_model.save_weights(weights_path)

model_path = model_name+".keras"
conv_model.save(model_path)
# Out:
# Epoch 1/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 8.7570 - mse: 8.7570 - val_loss: 1.0596 - val_mse: 1.0596
# Epoch 2/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9022 - mse: 0.9022 - val_loss: 0.7488 - val_mse: 0.7488
# Epoch 3/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.9262 - mse: 0.9262 - val_loss: 0.8718 - val_mse: 0.8718
# Epoch 4/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8376 - mse: 0.8376 - val_loss: 0.8276 - val_mse: 0.8276
# Epoch 5/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8172 - mse: 0.8172 - val_loss: 0.7593 - val_mse: 0.7593
# Epoch 6/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8211 - mse: 0.8211 - val_loss: 0.8253 - val_mse: 0.8253
# Epoch 7/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8254 - mse: 0.8254 - val_loss: 0.9424 - val_mse: 0.9424
# Epoch 8/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8694 - mse: 0.8694 - val_loss: 0.8244 - val_mse: 0.8244
# Epoch 9/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8548 - mse: 0.8548 - val_loss: 0.8429 - val_mse: 0.8429
# Epoch 10/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8575 - mse: 0.8575 - val_loss: 0.8604 - val_mse: 0.8604
# Epoch 11/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.8774 - mse: 0.8774 - val_loss: 0.8959 - val_mse: 0.8959
# Epoch 12/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.
200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1241 - mse: 0.1241 - val_loss: 0.1124 - val_mse: 0.1124
# Epoch 181/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1227 - mse: 0.1227 - val_loss: 0.0961 - val_mse: 0.0961
# Epoch 182/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1200 - mse: 0.1200 - val_loss: 0.1118 - val_mse: 0.1118
# Epoch 183/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1071 - mse: 0.1071 - val_loss: 0.0973 - val_mse: 0.0973
# Epoch 184/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1019 - mse: 0.1019 - val_loss: 0.1273 - val_mse: 0.1273
# Epoch 185/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1099 - mse: 0.1099 - val_loss: 0.1144 - val_mse: 0.1144
# Epoch 186/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0972 - mse: 0.0972 - val_loss: 0.1030 - val_mse: 0.1030
# Epoch 187/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1135 - mse: 0.1135 - val_loss: 0.1473 - val_mse: 0.1473
# Epoch 188/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1246 - mse: 0.1246 - val_loss: 0.1079 - val_mse: 0.1079
# Epoch 189/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1036 - mse: 0.1036 - val_loss: 0.1120 - val_mse: 0.1120
# Epoch 190/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0952 - mse: 0.0952 - val_loss: 0.0968 - val_mse: 0.0968
# Epoch 191/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1069 - mse: 0.1069 - val_loss: 0.1359 - val_mse: 0.1359
# Epoch 192/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1067 - mse: 0.1067 - val_loss: 0.0911 - val_mse: 0.0911
# Epoch 193/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0973 - mse: 0.0973 - val_loss: 0.0749 - val_mse: 0.0749
# Epoch 194/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0980 - mse: 0.0980 - val_loss: 0.0943 - val_mse: 0.0943
# Epoch 195/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1005 - mse: 0.1005 - val_loss: 0.1068 - val_mse: 0.1068
# Epoch 196/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0990 - mse: 0.0990 - val_loss: 0.1096 - val_mse: 0.1096
# Epoch 197/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1188 - mse: 0.1188 - val_loss: 0.1108 - val_mse: 0.1108
# Epoch 198/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0987 - mse: 0.0987 - val_loss: 0.1042 - val_mse: 0.1042
# Epoch 199/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.1061 - mse: 0.1061 - val_loss: 0.1035 - val_mse: 0.1035
# Epoch 200/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0853 - mse: 0.0853 - val_loss: 0.0856 - val_mse: 0.0856
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0743 - mse: 0.0743

# %%
df_loss_acc = pd.DataFrame(history.history)
print(df_loss_acc.columns)
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
df_mse= df_loss_acc[['mse','val_mse']]
df_mse.rename(columns={'mse':'train','val_mse':'validation'},inplace=True)

df_loss.plot(title='Model loss',figsize=(12,8)).set(xlabel='Epoch',ylabel='Loss')
plt.yscale('log')
fname = model_name  + "_training_hist.png"  #"training_hist_{}.png".format(datetime.now().strftime("%Y%m%d-%H%M%S"))
plt.savefig(fname)
# Out:
# Index(['loss', 'mse', 'val_loss', 'val_mse'], dtype='object')
# C:\Users\Linus\AppData\Local\Temp\ipykernel_17312\2160677342.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
# C:\Users\Linus\AppData\Local\Temp\ipykernel_17312\2160677342.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mse.rename(columns={'mse':'train','val_mse':'validation'},inplace=True)

# %%
## look at some data of model predictions vs labels
conv_model = tf.keras.models.load_model(r"Z:\lwoodard\Courses\Deep Learning\BDTNet\optcial_Q_Net\{}.keras".format(model_name))
predictions = []
labels = []
example_numbers = np.arange(32)
for batch_number in [1,2,3, 4, 5]:
    predicted, true = show_predicted_Qs(example_numbers, batch_number, test_dataset, conv_model)
    predictions.append(predicted)
    labels.append(true)

# pd.DataFrame({"CNN_predicted":predictions, "CNN_labels":labels}).to_csv(r"prediction_true_data.csv")
# Out:
# predicted Q = 601830.5900362455
# true Q = 357298.4938193156
#
# predicted Q = 468856.6262045882
# true Q = 732933.8701067939
#
# predicted Q = 15905.510865763412
# true Q = 23287.857261954778
#
# predicted Q = 468271.680913932
# true Q = 1880792.181865189
#
# predicted Q = 491580.44759434887
# true Q = 1400892.0811907938
#
# predicted Q = 21271.839243535254
# true Q = 20193.509029182558
#
# predicted Q = 396264.59173609776
# true Q = 70905.00189150948
#
# predicted Q = 2628.5333837810053
# true Q = 2008.637799401092
#
# predicted Q = 475271.08689694386
# true Q = 612214.8791223536
#
# predicted Q = 9400.242289912741
# true Q = 9212.108996371975
#
# predicted Q = 6051.2399939136
# true Q = 9093.02081127853
#
# predicted Q = 20167.794755018924
# true Q = 30097.567373667833
#
# predicted Q = 8644.225611245789
# true Q = 11831.431460533715
#
# predicted Q = 499176.47331992723
# true Q = 341757.9636034586
#
# predicted Q = 471299.44507483055
# true Q = 50035.503480405365
#
# predicted Q = 2608.41297778152
# true Q = 6621.02349966802
#
# predicted Q = 510846.12110553356
# true Q = 1221706.2197472875
#
# predicted Q = 475931.6576396656
# true Q = 270831.26213547704
#
# predicted Q = 3733.294879988609
# true Q = 4617.536379254313
#
# predicted Q = 503171.3978342053
# true Q = 811105.4804957979
#
# predicted Q = 8002.837869466738
# true Q = 21780.79818099506
#
# predicted Q = 533852.5035426772
# true Q = 558513.8992263892
#
# predicted Q = 4713.307528716885
# true Q = 6181.489585330935
#
# predicted Q = 6074.495408505081
# true Q = 5949.545501488185
#
# predicted Q = 8111.37672151263
# true Q = 18813.813519201387
#
# predicted Q = 485373.61492943316
# true Q = 114010.2101162914
#
# predicted Q = 504067.181287188
# true Q = 2046551.6973239246
#
# predicted Q = 10369.220663601169
# true Q = 6877.545692058913
#
# predicted Q = 6657.326927817114
# true Q = 8122.766500601722
#
# predicted Q = 541242.932743706
# true Q = 105765.3390743393
#
# predicted Q = 410821.96906132984
# true Q = 216978.10225442276
#
# predicted Q = 428709.9118842697
# true Q = 89472.46303083115
#
# predicted Q = 18243.590096129814
# true Q = 23882.582764390663
#
# predicted Q = 9130.489080987743
# true Q = 12318.79316113515
#
# predicted Q = 510846.12110553356
# true Q = 1221706.2197472875
#
# predicted Q = 566078.0063920366
# true Q = 260177.71776820545
#
# predicted Q = 10199.396747389193
# true Q = 10226.831746993925
#
# predicted Q = 448492.1604920131
# true Q = 891234.8867206039
#
# predicted Q = 3236.528113957978
# true Q = 5612.638001694447
#
# predicted Q = 29394.527741803315
# true Q = 39471.52905921617
#
# predicted Q = 491590.1629158535
# true Q = 247969.69377592872
#
# predicted Q = 5229.473146697691
# true Q = 3993.3105478724774
#
# predicted Q = 2862.9550374973314
# true Q = 5647.030806008522
#
# predicted Q = 9011.454281968632
# true Q = 23408.57556440722
#
# predicted Q = 3665.513608502332
# true Q = 4548.532175947178
#
# predicted Q = 4350.133627318645
# true Q = 6040.4436314529585
#
# predicted Q = 5094.455450107659
# true Q = 6154.052413308625
#
# predicted Q = 16729.761949226486
# true Q = 16414.586790339206
#
# predicted Q = 6957.626467378561
# true Q = 6151.47014391436
#
# predicted Q = 9253.747683140116
# true Q = 11494.836933299486
#
# predicted Q = 8002.837869466738
# true Q = 21780.79818099506
#
# predicted Q = 36216.66554817483
# true Q = 63252.354436528905
#
# predicted Q = 12911.698363615988
# true Q = 20444.62141815842
#
# predicted Q = 58637.26353772079
# true Q = 159419.3604569136
#
# predicted Q = 388226.43336433015
# true Q = 153896.76307274995
#
# predicted Q = 8458.605769518757
# true Q = 8222.14378218305
#
# predicted Q = 7786.929510600744
# true Q = 9611.713917308229
#
# predicted Q = 447572.2692672802
# true Q = 116886.25254214232
#
# predicted Q = 6657.326927817114
# true Q = 8122.7665006115485
#
# predicted Q = 520065.75105621194
# true Q = 1612779.6418369953
#
# predicted Q = 8111.37672151263
# true Q = 18813.813519201387
#
# predicted Q = 35481.39346323392
# true Q = 44537.779289879196
#
# predicted Q = 9134.700507736832
# true Q = 11136.532153444636
#
# predicted Q = 31149.63956860071
# true Q = 37794.52135988892
#
# predicted Q = 5958.316875881139
# true Q = 3040.1203509412717
#
# predicted Q = 9424.31082793884
# true Q = 13943.251634592818
#
# predicted Q = 5022.959569357205
# true Q = 5182.8575336152335
#
# predicted Q = 7527.893390362344
# true Q = 13808.24845412639
#
# predicted Q = 10714.245319316164
# true Q = 12288.821935882128
#
# predicted Q = 448394.1784992665
# true Q = 806047.8774069322
#
# predicted Q = 25200.94221731123
# true Q = 29331.280626753436
#
# predicted Q = 430201.81408289855
# true Q = 69345.48333152712
#
# predicted Q = 10360.810583051705
# true Q = 12834.274662325652
#
# predicted Q = 548595.9123346485
# true Q = 1462594.1540049857
#
# predicted Q = 7348.997567642525
# true Q = 11302.581060648325
#
# predicted Q = 9010.905170626373
# true Q = 9425.134696312252
#
# predicted Q = 469074.94583521533
# true Q = 1883066.7402010085
#
# predicted Q = 6915.031438646956
# true Q = 9082.976126012596
#
# predicted Q = 508193.86179270956
# true Q = 874943.1071102577
#
# predicted Q = 398002.19177480607
# true Q = 2130554.934684198
#
# predicted Q = 3516.0097581067703
# true Q = 4407.815287403179
#
# predicted Q = 430993.2443307405
# true Q = 146353.8510469147
#
# predicted Q = 444553.4104899098
# true Q = 202078.10218433113
#
# predicted Q = 28414.020913000757
# true Q = 28075.938091308115
#
# predicted Q = 413891.6031858634
# true Q = 831747.077533659
#
# predicted Q = 9134.700507736832
# true Q = 11136.532153428967
#
# predicted Q = 570839.5727528475
# true Q = 1043044.8041699048
#
# predicted Q = 57726.146369474816
# true Q = 15718.871491459757
#
# predicted Q = 24409.744218047923
# true Q = 42675.91974561802
#
# predicted Q = 384877.79598737403
# true Q = 368455.5373185608
#
# predicted Q = 2698.075605406518
# true Q = 2681.419900945964
#
# predicted Q = 6611.2329386090805
# true Q = 6331.7309681837405
#
# predicted Q = 22287.486070211886
# true Q = 33245.42109129002
#
# predicted Q = 5747.996269281456
# true Q = 6762.689667481879
#
# predicted Q = 4224.551243381866
# true Q = 1183.7731801948214
#
# predicted Q = 529015.3864204698
# true Q = 790970.5915633051
#
# predicted Q = 486124.0127077387
# true Q = 330349.0886744614
#
# predicted Q = 454591.5760833752
# true Q = 687771.087524574
#
# predicted Q = 4616.0767768399055
# true Q = 8744.909012161954
#
# predicted Q = 493965.9073319985
# true Q = 1213931.1244307365
#
# predicted Q = 11350.066284670049
# true Q = 26575.084272145737
#
# predicted Q = 486790.5815656908
# true Q = 303096.52902387135
#
# predicted Q = 24409.744218047923
# true Q = 42675.91974340171
#
# predicted Q = 6693.324344236275
# true Q = 15803.871014788256
#
# predicted Q = 56438.37700691066
# true Q = 115987.98497415232
#
# predicted Q = 400269.61102562345
# true Q = 131782.90242224463
#
# predicted Q = 1584.1609340667487
# true Q = 2758.6691452716714
#
# predicted Q = 4813.7753519054595
# true Q = 4215.286418498996
#
# predicted Q = 3941.5031554822167
# true Q = 3949.699325301923
#
# predicted Q = 9424.31082793884
# true Q = 13943.251634592818
#
# predicted Q = 6957.626467378561
# true Q = 6151.470143804401
#
# predicted Q = 486337.0231441054
# true Q = 616072.2032068584
#
# predicted Q = 4268.307495788639
# true Q = 7842.919932062349
#
# predicted Q = 526782.149549351
# true Q = 1257962.3057142694
#
# predicted Q = 414854.3069064745
# true Q = 215572.47090479088
#
# predicted Q = 4870.544167847463
# true Q = 8147.346669917516
#
# predicted Q = 463017.0269009466
# true Q = 1401059.0451786357
#
# predicted Q = 4121.99345534913
# true Q = 6724.445006485011
#
# predicted Q = 5652.4142433239995
# true Q = 4372.884287861578
#
# predicted Q = 436459.147142954
# true Q = 3706414.5321067907
#
# predicted Q = 1607.8160602589
# true Q = 2122.4071812251777
#
# predicted Q = 425242.670670265
# true Q = 869078.8115615839
#
# predicted Q = 41079.174879632956
# true Q = 47476.342057024354
#
# predicted Q = 8336.024758130116
# true Q = 8850.3061539188
#
# predicted Q = 430201.81408289855
# true Q = 69345.48333152712
#
# predicted Q = 4355.388301334283
# true Q = 4682.824768423699
#
# predicted Q = 489505.24220549036
# true Q = 92263.67139596083
#
# predicted Q = 440541.3739864243
# true Q = 420289.978836279
#
# predicted Q = 3650.841259924122
# true Q = 6316.166637791301
#
# predicted Q = 6051.2399939136
# true Q = 9093.020811324714
#
# predicted Q = 11507.874100308332
# true Q = 12155.823749576357
#
# predicted Q = 555735.6771009624
# true Q = 835714.0692806506
#
# predicted Q = 489505.24220549036
# true Q = 92263.67139596083
#
# predicted Q = 515546.53900259646
# true Q = 102274.47047743117
#
# predicted Q = 5883.967266807344
# true Q = 5971.07654568751
#
# predicted Q = 544151.3121901994
# true Q = 1926823.48237385
#
# predicted Q = 4998.9551685207825
# true Q = 57745.78224413585
#
# predicted Q = 450709.60009612027
# true Q = 229050.516039306
#
# predicted Q = 25200.94221731123
# true Q = 29331.280620302587
#
# predicted Q = 18557.78236541727
# true Q = 23232.140306615052
#
# predicted Q = 9138.642959107057
# true Q = 10279.5195455493
#
# predicted Q = 475769.6937642988
# true Q = 180068.72308964067
#
# predicted Q = 2042.8554901691487
# true Q = 2479.13530728349
#
# predicted Q = 451596.7668365088
# true Q = 668101.1184538421
#
# predicted Q = 3725.431041529586
# true Q = 2688.740839711348
#
# predicted Q = 413891.6031858634
# true Q = 831747.077533659
#
# predicted Q = 7879.924295625645
# true Q = 14492.585064054498
#
# predicted Q = 446045.5935731439
# true Q = 384248.4998088139
#
# predicted Q = 486124.0127077387
# true Q = 330349.0886744614
#
# predicted Q = 7398.10276048463
# true Q = 8622.040647619093
#
# predicted Q = 439645.51375411265
# true Q = 933685.4409401262
#
# predicted Q = 1625.0926788047084
# true Q = 1499.372576806316
#
# predicted Q = 6657.326927817114
# true Q = 8122.766500601722
#
# predicted Q = 442864.3809980079
# true Q = 134535.54254071592
#
# predicted Q = 8644.225611245789
# true Q = 11831.431460533715
#
# predicted Q = 2789.9517653274856
# true Q = 9449.856431146061
#
# predicted Q = 11348.770321314745
# true Q = 19909.11541226727
#
# predicted Q = 9678.756817316218
# true Q = 6006.875318975843
#
# predicted Q = 4813.7753519054595
# true Q = 4215.2864184662285
#
# predicted Q = 7398.10276048463
# true Q = 8622.040647569173

# %%
plt.scatter(labels, predictions)
plt.plot([min(labels[0]), max(labels[0])], [min(labels[0]), max(labels[0])], 'r--', label = "FDTD = CNN")
plt.xscale('log')
plt.yscale('log')
plt.xlabel("FDTD Q")
plt.ylabel("CNN Predicted Q")
plt.legend()
fname = "model_prediction_" + model_name + ".png" #"model_prediciton_{}.png".format(datetime.now().strftime("%Y%m%d-%H%M%S"))
plt.savefig(fname, dpi = 400, bbox_inches = 'tight')

# %%
performance = conv_model.evaluate(test_dataset)
print(performance)
# print('\n', np.array(labels[0]),  '\n\n', np.array(predictions[0]), '\n')
# ms = ((np.array(labels[0]) - np.array(predictions[0]))**2
rmse = (np.mean((np.log10(np.array(labels[0])) - np.log10(np.array(predictions[0])))**2))**0.5
print(10**rmse)
print(ms, mse, )
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - loss: 0.0083 - mse: 0.0083
# [0.010735058225691319, 0.010735058225691319]
# 1.19963779560134
# [6.79366138e+06 1.06302649e+06 8.50726394e+05 4.42816377e+06
#  1.49768367e+05 2.03315132e+03 1.34943441e+04 1.25448106e+05
#  5.60346049e+05 1.54521244e+04 2.25524182e+04 1.35060208e+07
#  5.08592428e+05 3.54238511e+06 1.48847204e+07 1.72370365e+06
#  1.83632046e+06 1.01781078e+05 5.27120294e+06 4.40198536e+01
#  1.00136176e+07 2.00101218e+04 2.76983069e+06 3.56461812e+06
#  3.40567686e+07 8.34138778e+06 7.93888865e+03 1.64391906e+06
#  1.35916354e+06 5.65404243e+05 3.85344240e+05 1.14426160e+07] 0.07905014011726974

# %% [markdown]
# ## CNN with custom loss

# %%
def custom_loss(y_true, y_pred):
    r"""
    impliments the custom loss funciton
        L(y_pred, y_true) = 1/n * \Sum_{i=1}^n y_true,i * (y_pred,i-y_true,i)**2
    """
    diff = tf.math.squared_difference(y_pred, y_true)  #squared difference
    diff_weighted = tf.math.multiply(y_true, diff)
    loss = tf.math.reduce_mean(diff_weighted, axis=-1) #mean over last dimension
    return loss

def CNN_model_custom_loss(input_shape, kernel_sizes = [6, 2], filters = [8, 16], pool_sizes = [8, 4], FC_nodes = [10], lr = 0.01):
        """
        Implements the forward propagation for the model:
        CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> DENSE
    
        Arguments:
        input_img -- input dataset, of shape (input_shape)
        kernel_size -- list of kernel sizes for each Conv2D step
        pool_size -- list of pool sizes for each MaxPool2D step
    
        Returns:
        model -- TF Keras model (object containing the information for the entire training process) 
        """
    
        input_img = tf.keras.Input(shape=input_shape)
    
        P = input_img
        
        for kernel_size, num_filters, pool_size in zip(kernel_sizes, filters, pool_sizes):
            Z = tfl.Conv2D(filters = num_filters, kernel_size = (kernel_size, kernel_size), strides = 1, padding = 'same')(P)
            A = tfl.ReLU()(Z)
            P = tfl.MaxPool2D(pool_size = (pool_size, pool_size), strides = 2, padding = 'same')(A)
        
        F = tfl.Flatten()(P)
        A = F

        for node in FC_nodes:
            A = tfl.Dense(node, activation = 'relu')(F)
    
        output = tfl.Dense(1)(A)
        
        model = tf.keras.Model(inputs=input_img, outputs=output)
        optimizer = keras.optimizers.Adam(learning_rate = lr)
        model.compile(optimizer=optimizer,
                          loss=custom_loss,
                          metrics =['mse'])
        return model

# %%
## train model with best performing parameters from the random search
## best performer from CNN_Optical_Q_hyperparams_20241112-212236.json
kernel_sizes, filters, pool_sizes, FC_nodes, lr = [10, 10], [23, 24], [10, 2], [64], 0.0019715835257217303
# kernel_sizes, filters, pool_sizes, FC_nodes, lr = [9, 4, 4, 2],	[15, 22, 23, 23], [10, 6, 1, 1], [128, 128, 16], 0.0024823465484887066
# kernel_sizes, filters, pool_sizes, FC_nodes, lr = [10, 5], [16, 24], [10, 1], [128, 64, 16], 0.0010438169495987548
# kernel_sizes, filters, pool_sizes, FC_nodes, lr = [3, 2], [16, 24], [1], [64], 0.0010438169495987548


model = CNN_model_custom_loss(paramsShape, kernel_sizes, filters, pool_sizes, FC_nodes, lr)

history = model.fit(train_dataset, epochs=200, validation_data=test_dataset)
performance = model.evaluate(test_dataset)

# save the model weights for transfer learning or just bringing the model back to life later
model_name = "custom_loss_model_{}".format(datetime.now().strftime("%Y%m%d-%H%M%S"))

weights_path = model_name + ".weights.h5"
model.save_weights(weights_path)

model_path = model_name+".keras"
model.save(model_path)
# Out:
# Epoch 1/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 32.1587 - mse: 6.3643 - val_loss: 4.2861 - val_mse: 0.9752
# Epoch 2/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 4.5453 - mse: 0.9939 - val_loss: 4.5954 - val_mse: 1.0722
# Epoch 3/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4129 - mse: 0.9495 - val_loss: 4.9584 - val_mse: 0.8983
# Epoch 4/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4339 - mse: 0.9232 - val_loss: 4.6968 - val_mse: 0.9083
# Epoch 5/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.4909 - mse: 0.9285 - val_loss: 4.1150 - val_mse: 0.9773
# Epoch 6/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.2103 - mse: 0.9052 - val_loss: 3.4732 - val_mse: 0.7039
# Epoch 7/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.1381 - mse: 0.8715 - val_loss: 4.2118 - val_mse: 0.9567
# Epoch 8/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.3733 - mse: 0.9804 - val_loss: 4.3818 - val_mse: 0.8631
# Epoch 9/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 3.9229 - mse: 0.8409 - val_loss: 4.4932 - val_mse: 0.8520
# Epoch 10/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 4.
200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4093 - mse: 0.0772 - val_loss: 0.3516 - val_mse: 0.0651
# Epoch 179/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.4730 - mse: 0.0865 - val_loss: 0.3817 - val_mse: 0.0708
# Epoch 180/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4023 - mse: 0.0748 - val_loss: 0.5504 - val_mse: 0.1125
# Epoch 181/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4860 - mse: 0.0916 - val_loss: 0.3795 - val_mse: 0.0703
# Epoch 182/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4876 - mse: 0.0932 - val_loss: 0.3836 - val_mse: 0.0681
# Epoch 183/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4137 - mse: 0.0757 - val_loss: 0.3149 - val_mse: 0.0608
# Epoch 184/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4894 - mse: 0.0929 - val_loss: 0.3573 - val_mse: 0.0632
# Epoch 185/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3586 - mse: 0.0663 - val_loss: 0.7472 - val_mse: 0.1586
# Epoch 186/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4663 - mse: 0.0891 - val_loss: 0.3444 - val_mse: 0.0624
# Epoch 187/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3742 - mse: 0.0676 - val_loss: 0.4086 - val_mse: 0.0698
# Epoch 188/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4445 - mse: 0.0802 - val_loss: 0.3016 - val_mse: 0.0582
# Epoch 189/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4656 - mse: 0.0826 - val_loss: 0.2902 - val_mse: 0.0515
# Epoch 190/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4427 - mse: 0.0816 - val_loss: 0.3854 - val_mse: 0.0690
# Epoch 191/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.3870 - mse: 0.0700 - val_loss: 0.3916 - val_mse: 0.0680
# Epoch 192/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4067 - mse: 0.0757 - val_loss: 0.5735 - val_mse: 0.1153
# Epoch 193/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4108 - mse: 0.0772 - val_loss: 0.6162 - val_mse: 0.1201
# Epoch 194/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.5359 - mse: 0.1016 - val_loss: 0.3926 - val_mse: 0.0741
# Epoch 195/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3925 - mse: 0.0721 - val_loss: 0.3242 - val_mse: 0.0576
# Epoch 196/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.3720 - mse: 0.0684 - val_loss: 0.3400 - val_mse: 0.0625
# Epoch 197/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4565 - mse: 0.0850 - val_loss: 0.4099 - val_mse: 0.0778
# Epoch 198/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4309 - mse: 0.0807 - val_loss: 0.3801 - val_mse: 0.0725
# Epoch 199/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.4324 - mse: 0.0788 - val_loss: 0.3758 - val_mse: 0.0730
# Epoch 200/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8025 - mse: 0.1618 - val_loss: 0.5233 - val_mse: 0.1111
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.6796 - mse: 0.1416

# %%
df_loss_acc = pd.DataFrame(history.history)
print(df_loss_acc.columns)
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
df_mse= df_loss_acc[['mse','val_mse']]
df_mse.rename(columns={'mse':'train','val_mse':'validation'},inplace=True)

df_loss.plot(title='Model loss',figsize=(12,8)).set(xlabel='Epoch',ylabel='Loss')
plt.yscale('log')
fname = model_name  + "_training_hist.png"  #"training_hist_{}.png".format(datetime.now().strftime("%Y%m%d-%H%M%S"))
plt.savefig(fname)
# Out:
# Index(['loss', 'mse', 'val_loss', 'val_mse'], dtype='object')
# C:\Users\Linus\AppData\Local\Temp\ipykernel_17312\2160677342.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
# C:\Users\Linus\AppData\Local\Temp\ipykernel_17312\2160677342.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mse.rename(columns={'mse':'train','val_mse':'validation'},inplace=True)

# %%
## look at some data of model predictions vs labels
# conv_model = tf.keras.models.load_model(r"Z:\lwoodard\Courses\Deep Learning\BDTNet\optcial_Q_Net\{}.keras".format(model_name)) need to figure out how to load model with custom loss
predictions = []
labels = []
example_numbers = np.arange(32)
for batch_number in [1,2,3, 4, 5]:
    predicted, true = show_predicted_Qs(example_numbers, batch_number, test_dataset, model)
    predictions.append(predicted)
    labels.append(true)
# Out:
# predicted Q = 5964.934492372448
# true Q = 5894.055319848679
#
# predicted Q = 703888.1633205827
# true Q = 883831.785761376
#
# predicted Q = 661912.0758992734
# true Q = 212691.85117262462
#
# predicted Q = 33003.67614725639
# true Q = 23201.263111540185
#
# predicted Q = 65934.00244154788
# true Q = 5529.974632353174
#
# predicted Q = 9373.512663562728
# true Q = 8791.880957983934
#
# predicted Q = 724693.9384250147
# true Q = 1045466.5927597221
#
# predicted Q = 4574.743761813786
# true Q = 3983.2089406378936
#
# predicted Q = 751546.8493841232
# true Q = 497627.9821218704
#
# predicted Q = 8693.171116708525
# true Q = 7483.545552044857
#
# predicted Q = 34658.7236184245
# true Q = 20308.996071392696
#
# predicted Q = 11642.192980452059
# true Q = 6181.489585384296
#
# predicted Q = 36955.77090958447
# true Q = 40091.4207447292
#
# predicted Q = 823160.3220441471
# true Q = 1098479.4458939454
#
# predicted Q = 20554.739981534276
# true Q = 10097.026499910038
#
# predicted Q = 2135.6214717163098
# true Q = 1593.45255017932
#
# predicted Q = 9365.509120780824
# true Q = 6465.23457783126
#
# predicted Q = 19171.546463896477
# true Q = 11831.431460533715
#
# predicted Q = 708213.0687909117
# true Q = 258033.85529364247
#
# predicted Q = 13683.106032317848
# true Q = 6154.052413077696
#
# predicted Q = 1324.3596472338481
# true Q = 1160.9273155211154
#
# predicted Q = 20117.70227970065
# true Q = 12155.823749680943
#
# predicted Q = 708952.9414673855
# true Q = 326868.92585106805
#
# predicted Q = 17573.44208276036
# true Q = 9212.108996382978
#
# predicted Q = 489418.7193949928
# true Q = 158558.14781614504
#
# predicted Q = 34963.0363970139
# true Q = 26858.771605417496
#
# predicted Q = 12235.566254315972
# true Q = 5612.638001694447
#
# predicted Q = 12200.83465486932
# true Q = 11374.147352638878
#
# predicted Q = 21283.84740430942
# true Q = 31274.234738797317
#
# predicted Q = 43046.26267669819
# true Q = 34726.15399339025
#
# predicted Q = 6960.377116682349
# true Q = 3461.0953538667736
#
# predicted Q = 26411.2049682033
# true Q = 11981.793877704156
#
# predicted Q = 11700.268276966297
# true Q = 5960.058066498266
#
# predicted Q = 644023.606816377
# true Q = 759200.1635000461
#
# predicted Q = 110480.19095216208
# true Q = 66854.13868124569
#
# predicted Q = 706371.804619113
# true Q = 549163.3976363436
#
# predicted Q = 3322.5844664386104
# true Q = 2122.4071812965926
#
# predicted Q = 10209.334664722073
# true Q = 7063.19999461914
#
# predicted Q = 12464.10684844647
# true Q = 7891.867320937834
#
# predicted Q = 762028.7542809938
# true Q = 222396.46487874174
#
# predicted Q = 9011.098097825587
# true Q = 9611.713917308229
#
# predicted Q = 944149.8155484638
# true Q = 3706414.5321067907
#
# predicted Q = 6030.301170750201
# true Q = 3732.9844236673653
#
# predicted Q = 818994.4597467289
# true Q = 418867.99134989205
#
# predicted Q = 773876.0355449871
# true Q = 664985.351834924
#
# predicted Q = 7898.0360486049
# true Q = 3086.583334071474
#
# predicted Q = 37071.064177953274
# true Q = 25593.697404031336
#
# predicted Q = 9015.887973694566
# true Q = 11494.836933299486
#
# predicted Q = 8542.093701403937
# true Q = 4429.095399788798
#
# predicted Q = 21296.306605781032
# true Q = 9094.93744361632
#
# predicted Q = 698114.8987945386
# true Q = 601844.5418826964
#
# predicted Q = 19154.272565675343
# true Q = 7615.813299227655
#
# predicted Q = 14772.616908315842
# true Q = 12146.326505686458
#
# predicted Q = 650169.9678984458
# true Q = 681594.8634990605
#
# predicted Q = 1760.6757330761604
# true Q = 1163.511898274373
#
# predicted Q = 9015.887973694566
# true Q = 11494.836934103183
#
# predicted Q = 473784.64165366086
# true Q = 81602.35581164085
#
# predicted Q = 660660.3409538295
# true Q = 204115.61200651564
#
# predicted Q = 33003.67614725639
# true Q = 23201.263111540185
#
# predicted Q = 21125.06758955983
# true Q = 15214.758809218036
#
# predicted Q = 580534.8254899805
# true Q = 141796.48679855594
#
# predicted Q = 16253.594511152407
# true Q = 11705.101758112465
#
# predicted Q = 38271.64760449761
# true Q = 24255.905814400918
#
# predicted Q = 728513.7030158119
# true Q = 659135.1228422029
#
# predicted Q = 5964.934492372448
# true Q = 5894.055320125625
#
# predicted Q = 701610.4336796362
# true Q = 2393436.3136417917
#
# predicted Q = 15319.751220913136
# true Q = 12430.490215270112
#
# predicted Q = 19171.546463896477
# true Q = 11831.43146056159
#
# predicted Q = 803000.8682487883
# true Q = 655330.4330179449
#
# predicted Q = 8781.36021332008
# true Q = 5562.369370455705
#
# predicted Q = 1024635.910233025
# true Q = 2724196.7944846423
#
# predicted Q = 2443.5915894539676
# true Q = 1821.0970937435977
#
# predicted Q = 4199.564262129403
# true Q = 2758.6691452716714
#
# predicted Q = 3322.5844664386104
# true Q = 2122.4071812251777
#
# predicted Q = 6866.252202803188
# true Q = 3216.381930103942
#
# predicted Q = 617415.3344596741
# true Q = 848738.9687489847
#
# predicted Q = 59241.5482383219
# true Q = 18967.400198433468
#
# predicted Q = 28943.191697349317
# true Q = 21959.062344868453
#
# predicted Q = 661813.9716843816
# true Q = 180068.72308964067
#
# predicted Q = 659367.534243549
# true Q = 157656.8718363924
#
# predicted Q = 40983.71226234895
# true Q = 28721.426800967343
#
# predicted Q = 5579.914818947439
# true Q = 4220.712552777174
#
# predicted Q = 11642.192980452059
# true Q = 6181.489585330935
#
# predicted Q = 3283.358625549838
# true Q = 3533.0741299090946
#
# predicted Q = 6773.191906266516
# true Q = 4548.532175943001
#
# predicted Q = 636704.4892600836
# true Q = 1072777.6513396862
#
# predicted Q = 3828.955259554717
# true Q = 2688.7408397407994
#
# predicted Q = 2481.648928132706
# true Q = 2442.565835530399
#
# predicted Q = 24273.255161600056
# true Q = 9449.856431146061
#
# predicted Q = 178214.16915070332
# true Q = 60716.943783811344
#
# predicted Q = 4932.052998469647
# true Q = 5382.7685279457655
#
# predicted Q = 802201.599460472
# true Q = 357298.4938193156
#
# predicted Q = 664617.4724273914
# true Q = 256995.4696460362
#
# predicted Q = 713113.1975174939
# true Q = 4253259.148839192
#
# predicted Q = 3221.457076633403
# true Q = 3104.658572357352
#
# predicted Q = 25733.881382807653
# true Q = 20184.503299214586
#
# predicted Q = 820168.7850769523
# true Q = 598939.6645814495
#
# predicted Q = 34658.7236184245
# true Q = 20308.99607154496
#
# predicted Q = 14772.616908315842
# true Q = 12146.326504865652
#
# predicted Q = 7607.284160027183
# true Q = 2681.4199009343106
#
# predicted Q = 9745.96493185959
# true Q = 9439.520578114278
#
# predicted Q = 11442.333326223748
# true Q = 9305.494109693893
#
# predicted Q = 851272.2823689785
# true Q = 1954293.5033550998
#
# predicted Q = 659747.721730228
# true Q = 116886.25254214232
#
# predicted Q = 11036.29535626246
# true Q = 8118.956747659078
#
# predicted Q = 70228.09487012957
# true Q = 37794.52136320946
#
# predicted Q = 704693.1494343941
# true Q = 81427.34636675344
#
# predicted Q = 762031.264312131
# true Q = 6125715.254700561
#
# predicted Q = 36010.44037777973
# true Q = 29331.280626753436
#
# predicted Q = 9237.759153131386
# true Q = 6331.7309672734855
#
# predicted Q = 661912.0758992734
# true Q = 212691.85117262462
#
# predicted Q = 43494.029202125676
# true Q = 23408.57556440722
#
# predicted Q = 6509.864214003663
# true Q = 3040.1203509412717
#
# predicted Q = 70228.09487012957
# true Q = 37794.52135988892
#
# predicted Q = 34594.472279229776
# true Q = 14462.593690937814
#
# predicted Q = 732928.7537213287
# true Q = 202715.00516104055
#
# predicted Q = 13683.106032317848
# true Q = 6154.052413077696
#
# predicted Q = 3853.289527519966
# true Q = 1764.4732519963302
#
# predicted Q = 16539.59735931758
# true Q = 14317.48286197991
#
# predicted Q = 690181.8091947928
# true Q = 185045.7777415904
#
# predicted Q = 632155.8559241374
# true Q = 463868.9876790946
#
# predicted Q = 621316.6993084004
# true Q = 320075.6099107448
#
# predicted Q = 766544.2318899671
# true Q = 223799.57047030074
#
# predicted Q = 5049.138316892949
# true Q = 6254.178395194781
#
# predicted Q = 851723.8435130145
# true Q = 933244.5656063117
#
# predicted Q = 28312.68568684962
# true Q = 18892.02270754207
#
# predicted Q = 15154.546542980068
# true Q = 5796.2399871982525
#
# predicted Q = 688822.1580543799
# true Q = 202078.10218433113
#
# predicted Q = 10209.334664722073
# true Q = 7063.199994160974
#
# predicted Q = 4572.479005010745
# true Q = 3886.654116806223
#
# predicted Q = 688822.1580543799
# true Q = 202078.10218433113
#
# predicted Q = 621780.0720439955
# true Q = 215968.59244075554
#
# predicted Q = 6321.686965468109
# true Q = 1762.2878938757012
#
# predicted Q = 673619.173476397
# true Q = 631479.1599412046
#
# predicted Q = 660660.3409538295
# true Q = 204115.61200651564
#
# predicted Q = 8693.171116708525
# true Q = 7483.545552056771
#
# predicted Q = 101847.3724359308
# true Q = 75681.1199373234
#
# predicted Q = 644023.606816377
# true Q = 759200.1635000461
#
# predicted Q = 649483.5977003477
# true Q = 443603.6781445202
#
# predicted Q = 33560.826918770304
# true Q = 19053.96962656332
#
# predicted Q = 54217.5538240116
# true Q = 33513.73257581017
#
# predicted Q = 642914.3989124903
# true Q = 456227.242302703
#
# predicted Q = 8781.36021332008
# true Q = 5562.369370455705
#
# predicted Q = 803000.8682487883
# true Q = 655330.4330179449
#
# predicted Q = 1504.9735186017929
# true Q = 910.634235894381
#
# predicted Q = 18775.3560051472
# true Q = 13943.251637063195
#
# predicted Q = 657630.8783003379
# true Q = 441902.37030613923
#
# predicted Q = 579974.1818006631
# true Q = 133513.40070491922
#
# predicted Q = 842606.582247704
# true Q = 845080.3395996713
#
# predicted Q = 35791.200380778224
# true Q = 21609.679108069824
#
# predicted Q = 6180.484749619894
# true Q = 6151.470143804401
#
# predicted Q = 33560.826918770304
# true Q = 19053.969626685015
#
# predicted Q = 647089.1345306222
# true Q = 215572.47090479088
#
# predicted Q = 50865.216627882946
# true Q = 24510.133894240364
#
# predicted Q = 17573.44208276036
# true Q = 9212.108996382978
#
# predicted Q = 26142.11708656409
# true Q = 8164.714530855441
#
# predicted Q = 575017.0840428539
# true Q = 92263.67139596083
#
# predicted Q = 48304.980266392864
# true Q = 39471.52905921617
#
# predicted Q = 33560.826918770304
# true Q = 19053.96962684338
#
# predicted Q = 571417.1087844481
# true Q = 69345.48333140487

# %%
plt.scatter(labels, predictions)
plt.plot([min(labels[0]), max(labels[0])], [min(labels[0]), max(labels[0])], 'r--', label = "FDTD = CNN")
plt.xscale('log')
plt.yscale('log')
plt.xlabel("FDTD Q")
plt.ylabel("CNN Predicted Q")
plt.legend()
fname = "model_prediction_" + model_name + ".png" #"model_prediciton_{}.png".format(datetime.now().strftime("%Y%m%d-%H%M%S"))
plt.savefig(fname, dpi = 400, bbox_inches = 'tight')

# %% [markdown]
# ## CNN with dropout
# Taking best preforming network and adding dropout to the model to increase generalization.  With this model, seems that we can acuratly predict Q to one significant digit and most of the time to two significant digits.

# %%
def CNN_model_w_dropout(input_shape, kernel_sizes = [6, 2], filters = [8, 16], pool_sizes = [8, 4], FC_nodes = [10], lr = 0.01):
        """
        Implements the forward propagation for the model:
        CONV2D -> RELU -> MAXPOOL -> CONV2D -> RELU -> MAXPOOL -> FLATTEN -> DENSE
    
        Arguments:
        input_img -- input dataset, of shape (input_shape)
        kernel_size -- list of kernel sizes for each Conv2D step
        pool_size -- list of pool sizes for each MaxPool2D step
    
        Returns:
        model -- TF Keras model (object containing the information for the entire training process) 
        """
    
        input_img = tf.keras.Input(shape=input_shape)
    
        P = input_img
        
        for kernel_size, num_filters, pool_size in zip(kernel_sizes, filters, pool_sizes):
            Z = tfl.Conv2D(filters = num_filters, kernel_size = (kernel_size, kernel_size), strides = 1, padding = 'same')(P)
            A = tfl.ReLU()(Z)
            P = tfl.MaxPool2D(pool_size = (pool_size, pool_size), strides = 2, padding = 'same')(A)
        
        F = tfl.Flatten()(P)
        A = F

        drop_layer = 1
        for node in FC_nodes:
            A = tfl.Dense(node, activation = 'relu')(F)
            if drop_layer == 1:
                A = tfl.Dropout(rate = 0.01)(A)
            drop_layer += 1
    
        output = tfl.Dense(1)(A)
        
        model = tf.keras.Model(inputs=input_img, outputs=output)

        optimizer = keras.optimizers.Adam(learning_rate = lr)
        model.compile(optimizer=optimizer,
                      loss='mse',
                      metrics =['mse'])
    
        return model

# %%
## best performer from CNN_Optical_Q_hyperparams_20241112-212236.json
kernel_sizes, filters, pool_sizes, FC_nodes, lr = [10, 10], [23, 24], [10, 2], [64], 0.0019715835257217303 * 0.1

conv_model_w_dropout = CNN_model_w_dropout(paramsShape, kernel_sizes, filters, pool_sizes, FC_nodes, lr)

history = conv_model_w_dropout.fit(train_dataset, epochs=200, validation_data=test_dataset)
performance = conv_model_w_dropout.evaluate(test_dataset)

model_name = "conv_model_w_dropout_{}".format(datetime.now().strftime("%Y%m%d-%H%M%S"))

weights_path = model_name + ".weights.h5"
# conv_model_w_dropout.save_weights(weights_path)
# conv_model_w_dropout.save(model_path)
# Out:
# Epoch 1/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 8.5631 - mse: 8.5631 - val_loss: 1.2918 - val_mse: 1.2918
# Epoch 2/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 1.1163 - mse: 1.1163 - val_loss: 0.9408 - val_mse: 0.9408
# Epoch 3/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8542 - mse: 0.8542 - val_loss: 0.9409 - val_mse: 0.9409
# Epoch 4/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8665 - mse: 0.8665 - val_loss: 0.7927 - val_mse: 0.7927
# Epoch 5/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8431 - mse: 0.8431 - val_loss: 0.8611 - val_mse: 0.8611
# Epoch 6/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9109 - mse: 0.9109 - val_loss: 0.7690 - val_mse: 0.7690
# Epoch 7/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8854 - mse: 0.8854 - val_loss: 0.8702 - val_mse: 0.8702
# Epoch 8/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8485 - mse: 0.8485 - val_loss: 0.9536 - val_mse: 0.9536
# Epoch 9/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9026 - mse: 0.9026 - val_loss: 0.8756 - val_mse: 0.8756
# Epoch 10/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8547 - mse: 0.8547 - val_loss: 0.8452 - val_mse: 0.8452
# Epoch 11/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8749 - mse: 0.8749 - val_loss: 0.8181 - val_mse: 0.8181
# Epoch 12/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8106 - mse: 0.8106 - val_loss: 0.8366 - val_mse: 0.8366
# Epoch 13/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9128 - mse: 0.9128 - val_loss: 0.8497 - val_mse: 0.8497
# Epoch 14/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8258 - mse: 0.8258 - val_loss: 0.7734 - val_mse: 0.7734
# Epoch 15/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8888 - mse: 0.8888 - val_loss: 0.7204 - val_mse: 0.7204
# Epoch 16/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8732 - mse: 0.8732 - val_loss: 0.7819 - val_mse: 0.7819
# Epoch 17/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8969 - mse: 0.8969 - val_loss: 0.8528 - val_mse: 0.8528
# Epoch 18/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8312 - mse: 0.8312 - val_loss: 0.8271 - val_mse: 0.8271
# Epoch 19/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8376 - mse: 0.8376 - val_loss: 1.1029 - val_mse: 1.1029
# Epoch 20/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.9718 - mse: 0.9718 - val_loss: 0.7904 - val_mse: 0.7904
# Epoch 21/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8847 - mse: 0.8847 - val_loss: 0.8282 - val_mse: 0.8282
# Epoch 22/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.8045 - mse: 0.8045 - val_loss: 0.8952 - val_mse: 0.8952
# Epoch 23/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8392 - mse: 0.8392 - val_loss: 0.8268 - val_mse: 0.8268
# Epoch 24/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8383 - mse: 0.8383 - val_loss: 0.7543 - val_mse: 0.7543
# Epoch 25/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.8835 - mse: 0.8835 - val_loss: 0.7915 - val_mse: 0.7915
# Epoch 26/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.
200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0937 - mse: 0.0937 - val_loss: 0.0750 - val_mse: 0.0750
# Epoch 196/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.0858 - mse: 0.0858 - val_loss: 0.1185 - val_mse: 0.1185
# Epoch 197/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1060 - mse: 0.1060 - val_loss: 0.0900 - val_mse: 0.0900
# Epoch 198/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0895 - mse: 0.0895 - val_loss: 0.0820 - val_mse: 0.0820
# Epoch 199/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0756 - mse: 0.0756 - val_loss: 0.0771 - val_mse: 0.0771
# Epoch 200/200
# 31/31 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.0876 - mse: 0.0876 - val_loss: 0.0718 - val_mse: 0.0718
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0731 - mse: 0.0731

# %%
df_loss_acc = pd.DataFrame(history.history)
print(df_loss_acc.columns)
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
df_mse= df_loss_acc[['mse','val_mse']]
df_mse.rename(columns={'mse':'train','val_mse':'validation'},inplace=True)

df_loss.plot(title='Model loss',figsize=(12,8)).set(xlabel='Epoch',ylabel='Loss')
plt.yscale('log')
# plt.savefig("CNN_w_dropout_loss_history.png", dpi = 400,  bbox_inches = 'tight')
# Out:
# Index(['loss', 'mse', 'val_loss', 'val_mse'], dtype='object')
# C:\Users\Linus\AppData\Local\Temp\ipykernel_17312\3770745703.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
# C:\Users\Linus\AppData\Local\Temp\ipykernel_17312\3770745703.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mse.rename(columns={'mse':'train','val_mse':'validation'},inplace=True)

# %%
predictions = []
labels = []
example_numbers = np.arange(32)
for batch_number in [1,2,3, 4]:
    predicted, true = show_predicted_Qs(example_numbers, batch_number, test_dataset, conv_model)
    predictions.append(predicted)
    labels.append(true)

pd.DataFrame({"CNN_predicted":predictions, "CNN_labels":labels}).to_csv(r"prediction_true_data_CNN_w_dropout.csv")
plt.scatter(labels, predictions)
plt.plot([min(labels[0]), max(labels[0])], [min(labels[0]), max(labels[0])], 'r--', label = "FDTD = CNN")
plt.xscale('log')
plt.yscale('log')
plt.xlabel("FDTD Q")
plt.ylabel("CNN Predicted Q")
plt.legend()
plt.savefig("model_prediciton_CNN_w_dropout.png", dpi = 400, bbox_inches = 'tight')
# Out:
# predicted Q = 21586.24078981116
# true Q = 18979.77548521513
#
# predicted Q = 50274.3974563057
# true Q = 49243.36569777605
#
# predicted Q = 8788.739109675678
# true Q = 7866.390805749998
#
# predicted Q = 11271.39408547466
# true Q = 9167.073822399114
#
# predicted Q = 8343.272194594525
# true Q = 8730.271376179075
#
# predicted Q = 5751.14950796232
# true Q = 5796.2399871982525
#
# predicted Q = 5498.93368684981
# true Q = 5382.768527921751
#
# predicted Q = 1537.95972121021
# true Q = 1183.7731801948214
#
# predicted Q = 22529.360836091113
# true Q = 21780.79818099506
#
# predicted Q = 1262.8852687048832
# true Q = 1138.5786945380885
#
# predicted Q = 5864.663175938284
# true Q = 6014.837801738155
#
# predicted Q = 15983.185841067749
# true Q = 12308.131995456542
#
# predicted Q = 2078.1586056186493
# true Q = 1365.0019411260212
#
# predicted Q = 23678.743552716875
# true Q = 21796.62105089476
#
# predicted Q = 14672.879479707162
# true Q = 18530.951582937116
#
# predicted Q = 8119.948773627427
# true Q = 6807.049823557001
#
# predicted Q = 9113.202497535813
# true Q = 7758.093476417608
#
# predicted Q = 2083.5047212272275
# true Q = 1764.4732520001605
#
# predicted Q = 12571.432987625243
# true Q = 10275.522940807326
#
# predicted Q = 3033.4856050115854
# true Q = 3040.1203509412717
#
# predicted Q = 15329.829981650937
# true Q = 12165.399927987168
#
# predicted Q = 1042.285688218586
# true Q = 900.8285506814095
#
# predicted Q = 9852.13857700231
# true Q = 8187.857743133316
#
# predicted Q = 26143.925434959467
# true Q = 24255.905805331073
#
# predicted Q = 15945.885440425205
# true Q = 10110.067705862008
#
# predicted Q = 20741.250019501713
# true Q = 17853.103939434448
#
# predicted Q = 5557.930364644558
# true Q = 5647.030806008522
#
# predicted Q = 21353.506618357904
# true Q = 20071.35254790234
#
# predicted Q = 6348.6892287392575
# true Q = 5182.8575336152335
#
# predicted Q = 4972.64622235168
# true Q = 4220.7125528030565
#
# predicted Q = 5189.386575584975
# true Q = 4568.625558617189
#
# predicted Q = 18676.01024053189
# true Q = 15293.31664046024
#
# predicted Q = 44667.976673625984
# true Q = 32990.37746654189
#
# predicted Q = 16083.739964936825
# true Q = 11734.35108030697
#
# predicted Q = 14455.04332663782
# true Q = 12176.426467659898
#
# predicted Q = 6066.766995478744
# true Q = 5859.485863474004
#
# predicted Q = 13316.866505740085
# true Q = 11934.917230248313
#
# predicted Q = 47830.9971114174
# true Q = 47308.50357242517
#
# predicted Q = 12328.492005610744
# true Q = 13425.455950084443
#
# predicted Q = 4692.614218150251
# true Q = 3941.595543545667
#
# predicted Q = 9885.674870319066
# true Q = 6908.630257169947
#
# predicted Q = 1306.7358646350858
# true Q = 1163.5118982486208
#
# predicted Q = 13504.822254223785
# true Q = 10228.690294317881
#
# predicted Q = 4255.689244661081
# true Q = 3350.359186074205
#
# predicted Q = 3294.6670822305714
# true Q = 2501.694816029959
#
# predicted Q = 23380.20548675392
# true Q = 21609.679108069824
#
# predicted Q = 9643.561011986192
# true Q = 7169.923812353125
#
# predicted Q = 981.4873542515494
# true Q = 760.8417649936267
#
# predicted Q = 1833.1978657451846
# true Q = 2118.610558404071
#
# predicted Q = 4278.258981674222
# true Q = 3873.1455446875625
#
# predicted Q = 4249.731221662378
# true Q = 4183.54517664915
#
# predicted Q = 5479.551009173212
# true Q = 5612.6380016876865
#
# predicted Q = 8458.656849245444
# true Q = 6465.23457783126
#
# predicted Q = 28733.01343965553
# true Q = 31640.934943098422
#
# predicted Q = 14778.53829067485
# true Q = 12071.41863136206
#
# predicted Q = 72903.70107919542
# true Q = 85307.66071405883
#
# predicted Q = 16268.181043510205
# true Q = 12288.821932931613
#
# predicted Q = 48761.22288511145
# true Q = 52315.768162348555
#
# predicted Q = 11856.577669064298
# true Q = 10279.519549391116
#
# predicted Q = 17967.198337062684
# true Q = 16628.39106036416
#
# predicted Q = 26020.213738728045
# true Q = 23444.358113506107
#
# predicted Q = 25635.883285802713
# true Q = 21777.27568459467
#
# predicted Q = 28632.646796101766
# true Q = 23815.749669753775
#
# predicted Q = 6011.14725414012
# true Q = 5195.857937640012
#
# predicted Q = 6459.852857239338
# true Q = 6179.705336136585
#
# predicted Q = 33333.691766541895
# true Q = 32160.703184394446
#
# predicted Q = 10704.215501562918
# true Q = 9940.039762309621
#
# predicted Q = 13982.737758305406
# true Q = 10736.20016695496
#
# predicted Q = 30358.92947263901
# true Q = 22182.68568435247
#
# predicted Q = 8800.364992115086
# true Q = 7299.841764509844
#
# predicted Q = 10870.67003057538
# true Q = 8999.661485663404
#
# predicted Q = 9823.379743053434
# true Q = 7502.235550163869
#
# predicted Q = 6990.245610406751
# true Q = 6877.545692058913
#
# predicted Q = 4418.034482392452
# true Q = 3983.2089406378936
#
# predicted Q = 6892.791134820793
# true Q = 5883.856919398503
#
# predicted Q = 10335.496417737937
# true Q = 9849.723899841783
#
# predicted Q = 63555.62467961648
# true Q = 62114.673874078
#
# predicted Q = 36426.11138669959
# true Q = 28721.426801682836
#
# predicted Q = 29787.190370989436
# true Q = 31823.433638741077
#
# predicted Q = 165266.00062457254
# true Q = 159419.3604569136
#
# predicted Q = 4756.127459082211
# true Q = 3993.3105478724774
#
# predicted Q = 5594.865123293838
# true Q = 4407.815287403179
#
# predicted Q = 20369.43741825843
# true Q = 17660.810975062104
#
# predicted Q = 2355.552151305841
# true Q = 1647.7047596931995
#
# predicted Q = 2959.52276802688
# true Q = 3287.3539609851996
#
# predicted Q = 15718.898153739918
# true Q = 14317.48286197991
#
# predicted Q = 10430.275142421162
# true Q = 11302.581060648325
#
# predicted Q = 16312.628178755383
# true Q = 13943.251634592818
#
# predicted Q = 5729.2766608507445
# true Q = 5903.784363403217
#
# predicted Q = 32295.989686792363
# true Q = 30097.567373667833
#
# predicted Q = 7797.247305616208
# true Q = 7063.19999461914
#
# predicted Q = 2440.7452850603054
# true Q = 1593.45255017932
#
# predicted Q = 9652.453925741336
# true Q = 8344.406263404213
#
# predicted Q = 10263.72140885443
# true Q = 9094.93744361632
#
# predicted Q = 2105.2512694965535
# true Q = 1672.230234001265
#
# predicted Q = 30513.954957655158
# true Q = 28075.938091308115
#
# predicted Q = 1095.1702552113659
# true Q = 861.9216613394898
#
# predicted Q = 5222.1202776746995
# true Q = 4416.39814660886
#
# predicted Q = 10512.167589997061
# true Q = 9439.520578808595
#
# predicted Q = 4093.033395224727
# true Q = 3234.0840370252954
#
# predicted Q = 5878.039653571333
# true Q = 5246.658547103955
#
# predicted Q = 7155.072182234685
# true Q = 5964.583220729824
#
# predicted Q = 2154.4283820968826
# true Q = 1811.5712439774368
#
# predicted Q = 56830.87103520556
# true Q = 57745.78224413585
#
# predicted Q = 5362.676031522117
# true Q = 5844.410175345154
#
# predicted Q = 19574.033893978994
# true Q = 16903.59686655542
#
# predicted Q = 19905.43409161853
# true Q = 15076.576335608157
#
# predicted Q = 15592.16348342581
# true Q = 15277.568953023503
#
# predicted Q = 5287.012470489924
# true Q = 4617.536379246107
#
# predicted Q = 1109.654938037315
# true Q = 1148.2663239650365
#
# predicted Q = 15846.95872147098
# true Q = 13947.943116209399
#
# predicted Q = 17752.16662717152
# true Q = 19762.65199836052
#
# predicted Q = 7816.9282754879405
# true Q = 7906.390534401254
#
# predicted Q = 7835.970606297763
# true Q = 6762.689667481879
#
# predicted Q = 8945.804164780431
# true Q = 6293.691420616021
#
# predicted Q = 10134.573866165101
# true Q = 7948.655530802143
#
# predicted Q = 10872.818640187274
# true Q = 10221.750969906994
#
# predicted Q = 20797.4615570053
# true Q = 14803.689079834414
#
# predicted Q = 2035.98116514841
# true Q = 1499.3725768010647
#
# predicted Q = 2967.2290637552883
# true Q = 2072.9290400861887
#
# predicted Q = 15351.59172604345
# true Q = 13570.454414218779
#
# predicted Q = 28345.15822822625
# true Q = 26575.084272145737
#
# predicted Q = 24481.165636179485
# true Q = 23201.26311227859
#
# predicted Q = 3639.119307331418
# true Q = 3086.583334071474
#
# predicted Q = 16234.86725355693
# true Q = 15080.915618808698
#
# predicted Q = 3011.6390476666816
# true Q = 2060.323034848373
#
# predicted Q = 9747.126022785427
# true Q = 8297.222107937272
#
# predicted Q = 21499.740780880966
# true Q = 18557.649846946075

# %%
# retrieving a model
weights_path = r"conv_model_w_dropout_20241113-202125.weights.h5"

blank_model = CNN_model_w_dropout(paramsShape, kernel_sizes, filters, pool_sizes, FC_nodes, lr)
performace = blank_model.evaluate(test_dataset, verbose = 2)
# print(f'blank model performance {performace}')

loaded_model = CNN_model_w_dropout(paramsShape, kernel_sizes, filters, pool_sizes, FC_nodes, lr)
loaded_model.load_weights(weights_path)
performace =  loaded_model.evaluate(test_dataset, verbose = 2)
# print(f'loaded model performance {performace}')
# Out:
# 6/6 - 0s - 18ms/step - loss: 16.1564 - mse: 16.1564
# 6/6 - 0s - 18ms/step - loss: 0.0099 - mse: 0.0099

# %%
df_loss_acc = pd.DataFrame(history.history)
print(df_loss_acc.columns)
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
df_mse= df_loss_acc[['mse','val_mse']]
df_mse.rename(columns={'mse':'train','val_mse':'validation'},inplace=True)

df_loss.plot(title='Model loss',figsize=(12,8)).set(xlabel='Epoch',ylabel='Loss')
plt.yscale('log')
plt.savefig("CNN_w_dropout_loss_history.png", dpi = 400,  bbox_inches = 'tight')
# Out:
# Index(['loss', 'mse', 'val_loss', 'val_mse'], dtype='object')
# C:\Users\linus\AppData\Local\Temp\ipykernel_5544\2966314737.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
# C:\Users\linus\AppData\Local\Temp\ipykernel_5544\2966314737.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mse.rename(columns={'mse':'train','val_mse':'validation'},inplace=True)

# %% [markdown]
# ### Playing with the hyperparameters a bit

# %%
kernel_sizes, filters, pool_sizes, FC_nodes, lr = [8, 10], [15, 30], [10, 2], [64], 2e-4

conv_model = CNN_model(paramsShape, kernel_sizes, filters, pool_sizes, FC_nodes, lr)

history = conv_model.fit(train_dataset, epochs=450, validation_data=test_dataset, verbose = 0)
# save the model weights for transfer learning or just bringing the model back to life later -- don't rerun this cell
print(datetime.now().strftime("%Y%m%d-%H%M%S"))
weights_path = "conv_model_{}.weights.h5".format(datetime.now().strftime("%Y%m%d-%H%M%S"))
conv_model.save_weights(weights_path) ### should be saving the whole model.

performance = conv_model.evaluate(test_dataset, verbose = 2)

df_loss_acc = pd.DataFrame(history.history)
df_loss= df_loss_acc[['loss','val_loss']]
df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)

df_loss.plot(title='Model loss',figsize=(12,8)).set(xlabel='Epoch',ylabel='Loss')
plt.yscale('log')
# Out:
# 20241113-204719
# 6/6 - 0s - 2ms/step - loss: 0.0040 - mse: 0.0040
# C:\Users\Linus\AppData\Local\Temp\ipykernel_15044\2390506639.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_loss.rename(columns={'loss':'train','val_loss':'validation'},inplace=True)
# [Text(0.5, 0, 'Epoch'), Text(0, 0.5, 'Loss')]
